# %% [markdown]
# # Lab 03: Various SELECT commands in SQL
#
# #### **Data Query Language (DQL) Statements:**
#    - Used for querying and retrieving data from database tables.
#    - The primary DQL statement is SELECT.

# %% [markdown]
# ## About the Dataset
#
# The dataset is designed around a fictitious eCommerce company with millions of records to let a data analyst analyze multiple tables related to different aspects of a business. The database "dualcore" is set up, and six tables are created: employees, products, customers, orders, order_details, and suppliers.
#
# 1. employees Table:
#     - Columns: emp_id, fname, lname, address, city, state, zipcode, job_title, email, active, salary

# %% [markdown]
# 2. Products Table:
#    - Columns: prod_id, brand, name, price, cost, shipping_wt

# %% [markdown]
# 3. Customers Table:
#    - Columns: cust_id, fname, lname, address, city, state, zipcode

# %% [markdown]
# 4. Orders Table:
#    - Columns: order_id, cust_id, order_date
#    - Description: This table manages order information, including order IDs, customer IDs (linked to the customers table), and order dates.

# %% [markdown]
# 5. Order_details Table:
#    - Columns: order_id, prod_id
#    - Description: This table handles the details of each order, linking order IDs to the products purchased (linked to the products table).

# %% [markdown]
# 6. Suppliers Table:
#    - Columns: supp_id, company, contact, address, city, state, zipcode, phone

# %% [markdown]
# ## Let's get Started
#
#
# You can download the delimited text files from this link: https://drive.google.com/drive/folders/1JdZxGaeRddmhmEYNOs7p79f_3zEc9wuM?usp=sharing
#
# The LOAD command is used to populate these tables with data from corresponding CSV files. The syntax for LOAD command is as follows:
#
# ```sql
# LOAD DATA LOCAL INFILE '/path/to/data/file/{filename}.txt' INTO TABLE dualcore.{tablename};
# ```
#
# The above command loads data from the specified CSV file into the respective table in the "dualcore" database. The columns in the CSV files match the columns in the corresponding tables. This process efficiently imports large datasets into the database, allowing data analysts to perform various analyses and queries on the data.

# %% [markdown]
# # Connecting to and Showing the Database
#
# By using the following command you can load the Jupyter extension for MySQL database server runing on your machine.

# %%
# %load_ext sql

# %% [markdown]
# The following commands will help you connect to the specific database schema within your MySQL instance. In this case the name of the schema is **dualcore**.

# %% [markdown]
# Connect to the database using the following command. The general syntax is:
# ```
# %sql mysql://user:password@server[:port]/dbname
# ```

# %%
# %sql mysql://root:root@localhost:3306/dualcore

# %%
# %%sql
#
# SHOW tables;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 6 rows affected.
# [('customers',),
#  ('employees',),
#  ('order_details',),
#  ('orders',),
#  ('products',),
#  ('suppliers',)]

# %% [markdown]
# # The SELECT Statement
# As a data analyst, the most commonly used SQL statement is the SELECT statement. The SELECT statement is fundamental to retrieving and analyzing data from a database, and it forms the core of data querying and reporting tasks. Here are the reasons why the SELECT statement is so commonly used by data analysts:
#
# 1. **Data Retrieval:** The primary purpose of a data analyst is to retrieve data from a database for analysis. The SELECT statement allows data analysts to specify the columns they want to retrieve and apply filtering conditions to fetch relevant data.
#
# 2. **Data Exploration:** Data analysts often need to explore the data to gain insights and identify patterns. The SELECT statement allows them to retrieve different subsets of data, perform aggregations, and sort the data based on various criteria.
#
# 3. **Data Transformation:** Data analysts may need to transform the data before analysis, such as aggregating, calculating new metrics, or joining multiple tables. The SELECT statement, along with other clauses like GROUP BY and JOIN, enables these transformations.
#
# 4. **Filtering and Data Quality Checks:** Data analysts frequently apply filters to include or exclude specific data based on certain conditions. This helps in data quality checks and ensures that only relevant and accurate data is used for analysis.
#
# 5. **Reporting and Visualization:** SELECT statements are essential for generating data reports and providing data for visualization tools. Data analysts use SELECT to fetch the necessary data that feeds into reports and dashboards.
#
# 6. **Ad-hoc Analysis:** Data analysts often perform ad-hoc analysis to answer specific questions or investigate anomalies in the data. The SELECT statement's flexibility allows analysts to quickly query the data and derive insights on the fly.
#
# 7. **Performance Optimization:** Data analysts may optimize their SELECT queries to ensure that they run efficiently and quickly, especially when dealing with large datasets.
#
# Overall, the SELECT statement is a critical tool that empowers data analysts to access, explore, and analyze data effectively. Its flexibility and power make it an indispensable part of the data analyst's toolkit, making it the most commonly used SQL statement in their daily work.

# %% [markdown]
# ## Syntax of the SELECT Statement
#
# ```
# SELECT [DISTINCT]
#     Tablename1.columnname1,
#     Tablename2.columnname3,
#     .
#     .
#     TablenameX.columnnameY,
# FROM Tablename1
# [LEFT] JOIN Tablename2
#     ON conditions
# [LEFT] JOIN Tablename3
#     ON conditions
# .
# .
# [LEFT] JOIN TablenameX
#     ON conditions
# WHERE 1=1
#     AND conditions
# [GROUP BY] TablenameN.columnnameM, ...
# [HAVING] aggregated conditions
# [ORDER BY] TablenameL.columnnameO, ...
# [LIMIT] number;
# ```
#
# The SQL SELECT statement is used to retrieve data from multiple tables using JOINs and apply various filtering, grouping, and sorting operations. Here's a breakdown of the syntax:
#
# 1. **SELECT [DISTINCT]:** Specifies the columns you want to retrieve data from. You can use the DISTINCT keyword to eliminate duplicate rows in the result set.
#
# 2. **Tablename1.columnname1, Tablename2.columnname3, ... TablenameX.columnnameY:** Specifies the specific columns from multiple tables that you want to include in the result set.
#
# 3. **FROM Tablename1:** Specifies the main table (Tablename1) from which you want to retrieve data.
#
# 4. **[LEFT] JOIN Tablename2 ON conditions:** Joins Tablename2 with Tablename1 based on specified conditions. LEFT JOIN keeps all rows from the left table (Tablename1) and the matching rows from the right table (Tablename2).
#
# 5. **[LEFT] JOIN Tablename3 ON conditions:** Joins Tablename3 with the previously joined tables based on specified conditions.
#
# 6. **... LEFT JOIN TablenameX ON conditions:** Continues joining more tables using LEFT JOIN based on specified conditions.
#
# 7. **WHERE 1=1 AND conditions:** Optional clause to filter the result set based on specified conditions. 1=1 is a placeholder to which additional conditions are added using the AND keyword.
#
# 8. **[GROUP BY] TablenameN.columnnameM, ...:** Optional clause used for grouping data based on specified columns. It is used in combination with aggregate functions to perform calculations on grouped data.
#
# 9. **[HAVING] aggregated conditions:** Optional clause used with GROUP BY to filter grouped data based on specified conditions.
#
# 10. **[ORDER BY] TablenameL.columnnameO, ...:** Optional clause to sort the result set based on specified columns in ascending (default) or descending order.
#
# 11. **[LIMIT] number:** Optional clause to limit the number of rows returned in the result set.
#
# This SELECT statement allows you to fetch data from multiple tables by joining them using LEFT JOINs and apply various filtering, grouping, and sorting operations to shape the final result set. It offers significant flexibility in retrieving and analyzing data from complex database structures.
#
# In the examples that follow, we will cover extensively the simler aspects of the SQL statements. For more advanced concepts like Grouping, Aggregate functions, and Joins, we will just give a glimpse of the power of these concepts and will discuss them in more detail in a future lab.

# %% [markdown]
# ## Example 1: Describing a table
#
# before we fire away a query to the database let's first understand the table structure against which we will run our queries. To do so, use the DESCRIBE statement as follows:

# %%
# %%sql
#
# DESCRIBE employees;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 11 rows affected.
# [('emp_id', 'char(9)', 'NO', 'PRI', None, ''),
#  ('fname', 'varchar(15)', 'YES', '', None, ''),
#  ('lname', 'varchar(20)', 'YES', '', None, ''),
#  ('address', 'varchar(40)', 'YES', '', None, ''),
#  ('city', 'varchar(30)', 'YES', '', None, ''),
#  ('state', 'char(2)', 'YES', '', None, ''),
#  ('zipcode', 'char(5)', 'YES', '', None, ''),
#  ('job_title', 'varchar(35)', 'YES', '', None, ''),
#  ('email', 'varchar(25)', 'YES', '', None, ''),
#  ('active', 'char(1)', 'NO', '', 'Y', ''),
#  ('salary', 'int', 'YES', '', None, '')]

# %% [markdown]
# ## Example 2: Average Salary of ALL Enployees
#
# Let's start with a simple example and find the average salary of all employees.
# To find the average salary of active employees, we'll use the SQL SELECT statement and the AVG() function.

# %%
# %%sql
#
# SELECT AVG(salary) AS average_salary
# FROM employees;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 1 rows affected.
# [(Decimal('26246.6106'),)]

# %% [markdown]
# ## Example 3: Average Salary of Active Enployees
#
# To analyse the data let's now find the the average salary of all active employees.
# Before finding the saverage salary for employees we will filter them using a WHERE clause as follows

# %%
# %%sql
#
# SELECT AVG(salary) AS average_salary
# FROM employees
# WHERE active = 'Y';
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 1 rows affected.
# [(Decimal('26248.1952'),)]

# %% [markdown]
# ## Example 4: Number of Active employees Earning Average Salary or More
#
# Let's spin things a little and find how many employees are earning equal to or more than the average salary of all active employees.
# In this case, we'll first calculate the average salary of active employees inn a sub query. Then, we'll use that average salary value to count the number of employees meeting the condition.

# %%
# %%sql
#
# SELECT COUNT(*) AS num_employees_above_average
# FROM employees
# WHERE active = 'Y' AND salary >= (SELECT AVG(salary) FROM employees WHERE active = 'Y');
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 1 rows affected.
# [(16820,)]

# %% [markdown]
# ## Example 5: Filtering and Ordering Records
#
# Find out all the products with a price higher than $5000, ordered by their price in descending order.

# %%
# %%sql
#
# SELECT prod_id, brand, name, price
# FROM products
# WHERE price > 5000
# ORDER BY price DESC;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 588 rows affected.
# [(1274321, 'Byteweasel', 'Hadoop Cluster, Economy (4-node)', 975149),
#  (1274308, 'Gigabux', 'Server (2U rackmount, eight-core, 64GB, 12TB)', 614559),
#  (1274307, 'Krustybitz', 'Server (2U rackmount, eight-core, 64GB, 12TB)', 599319),
#  (1274306, 'United Digistuff', 'Server (2U rackmount, eight-core, 64GB, 12TB)', 597049),
#  (1274318, 'BuckLogix', 'Server (1U rackmount, hex-core, 32GB, 8TB)', 483989),
#  (1274319, 'BuckLogix', 'Server (1U rackmount, hex-core, 32GB, 8TB)', 478489),
#  (1274320, 'Sparky', 'Server (1U rackmount, hex-core, 32GB, 8TB)', 478459),
#  (1274315, 'Sparky', 'Server (1U rackmount, hex-core, 16GB, 8TB)', 470019),
#  (1274317, 'Krustybitz', 'Server (1U rackmount, hex-core, 16GB, 8TB)', 459179),
#  (1274316, 'Dualcore', 'Server (1U rackmount, hex-core, 16GB, 8TB)', 448239),
#  (1274312, 'Krustybitz', 'Server (1U rackmount, hex-core, 8GB, 4TB)', 409949),
#  (1274314, 'Lemmon', 'Server (1U rackmount, hex-core, 8GB, 4TB)', 397159),
#  (1274313, 'Olde-Gray', 'Server (1U rackmount, hex-core, 8GB, 4TB)', 393989),
#  (1274311, 'Yoyodyne', 'Server (1U rackmount, quad-core, 4GB, 2TB)', 300969),
#  (1274309, 'Yoyodyne', 'Server (1U rackmount, quad-core, 4GB, 2TB)', 299969),
#  (1274310, 'Electrosaurus', 'Server (1U rackmount, quad-core, 4GB, 2TB)', 295269),
#  (1274503, 'Foocorp', 'VPN Appliance (250 Clienti license)', 229329),
#  (1274502, 'BuckLogix', 'VPN Appliance (250 Clienti license)', 227269),
#  (1274334, 'Bitmonkey', 'All-in-one Desktop (24 in. display)', 194389),
#  (1274335, 'Bitmonkey', 'All-in-one Desktop (24 in. display)', 188579),
#  (1274332, 'Sparky', 'All-in-one Desktop (21 in. display)', 173989),
#  (1274333, 'Electrosaurus', 'All-in-one Desktop (21 in. display)', 173069),
#  (1274331, 'Dualcore', 'Premium Gamer Desktop', 131539),
#  (1274428, 'Lemmon', '61" Wide Screen TV', 131149),
#  (1274427, 'Whiteacre', '61" Wide Screen TV', 130799),
#  (1274330, 'Olde-Gray', 'Premium Gamer Desktop', 129219),
#  (1274429, 'Wernham', '61" Wide Screen TV', 128579),
#  (1274426, 'Gigabux', '61" Wide Screen TV', 122919),
#  (1274327, 'Yoyodyne', 'Professional Series Desktop', 91889),
#  (1274342, 'Lemmon', 'Premium Gamer Notebook', 91819),
#  (1274328, 'Dualcore', 'Professional Series Desktop', 90989),
#  (1274329, 'Homertech', 'Professional Series Desktop', 88319),
#  (1274343, 'SuperGamer', 'Premium Gamer Notebook', 87729),
#  (1274577, 'McDowell', 'Wide Format Printer', 87719),
#  (1274578, 'Olde-Gray', 'Wide Format Printer', 87619),
#  (1274394, 'Olde-Gray', '40" Large-Format LCD Display', 86159),
#  (1274396, 'Olde-Gray', '40" Large-Format LCD Display', 85979),
#  (1274395, 'Olde-Gray', '40" Large-Format LCD Display', 85219),
#  (1274345, 'Orion', 'Ultra-portable Notebook', 81959),
#  (1274696, 'Dorx', 'LTO Tape Backup Drive (SCSI)', 79969),
#  (1274697, 'Spindown', 'LTO Tape Backup Drive (SCSI)', 79959),
#  (1274344, 'Byteweasel', 'Ultra-portable Notebook', 79099),
#  (1274422, 'Wolfpack', '48" Wide Screen TV', 72699),
#  (1274420, 'Wolfpack', '48" Wide Screen TV', 72369),
#  (1274339, 'Krustybitz', 'Professional Series Notebook', 71159),
#  (1274569, 'Tyrell', 'Laser Printer (Black-and-White, Duplex)', 71149),
#  (1274424, 'Chestnut', '48" Wide Screen TV', 70939),
#  (1274340, 'SuperGamer', 'Professional Series Notebook', 70069),
#  (1274570, 'Tyrell', 'Laser Printer (Black-and-White, Duplex)', 69899),
#  (1274341, 'Orion', 'Professional Series Notebook', 68829),
#  (1274421, 'Electrosaurus', '48" Wide Screen TV', 68489),
#  (1273816, 'XYZ', 'VR Headset', 68399),
#  (1274423, 'Tyrell', '48" Wide Screen TV', 66759),
#  (1274568, 'McDowell', 'Laser Printer (Black-and-White, Duplex)', 66679),
#  (1274425, 'Wernham', '48" Wide Screen TV', 66309),
#  (1274419, 'McDowell', '48" Wide Screen TV', 64909),
#  (1274326, 'Olde-Gray', 'Basic Desktop', 63639),
#  (1274325, 'Dualcore', 'Basic Desktop', 63409),
#  (1274322, 'Olde-Gray', 'Home Media Server', 62469),
#  (1274695, 'Dualcore', 'DLT-III Tape Backup Drive (SCSI)', 62179),
#  (1274323, 'Dualcore', 'Home Media Server', 62139),
#  (1274324, 'Krustybitz', 'Basic Desktop', 61989),
#  (1274459, 'Chestnut', 'Digital Video Recorder (2.0 TB)', 60519),
#  (1274414, 'Chestnut', '42" Wide Screen TV', 59789),
#  (1274413, 'Electrosaurus', '42" Wide Screen TV', 58279),
#  (1274694, 'Lemmon', 'DLT-III Tape Backup Drive (SCSI)', 58159),
#  (1274415, 'McDowell', '42" Wide Screen TV', 58029),
#  (1274417, 'McDowell', '42" Wide Screen TV', 56919),
#  (1274418, 'McDowell', '42" Wide Screen TV', 55649),
#  (1274412, 'ARCAM', '42" Wide Screen TV', 55559),
#  (1274416, 'Lemmon', '42" Wide Screen TV', 55169),
#  (1274602, 'DevNull', 'Office Suite (Enterprise Edition)', 50539),
#  (1274387, 'Olde-Gray', '30" Wide Screen LCD Monitor', 50349),
#  (1274501, 'TPS', 'VPN Appliance (50 Clienti license)', 50159),
#  (1274499, 'Duff', 'VPN Appliance (50 Clienti license)', 50029),
#  (1274388, 'ElCheapo', '30" Wide Screen LCD Monitor', 49949),
#  (1274349, 'United Digistuff', 'Tablet PC (10 in. display, 64 GB)', 49579),
#  (1274610, 'United Digistuff', '173 GB SAS Disk', 49459),
#  (1274386, 'Wernham', '30" Wide Screen LCD Monitor', 49419),
#  (1274350, 'Orion', 'Tablet PC (10 in. display, 64 GB)', 49069),
#  (1274613, 'Megachango', '173 GB SAS Disk', 48709),
#  (1274612, 'Krustybitz', '173 GB SAS Disk', 48519),
#  (1274456, 'Whiteacre', 'Digital Video Recorder (1.5 TB)', 48139),
#  (1274500, 'Dualcore', 'VPN Appliance (50 Clienti license)', 48049),
#  (1274576, 'ACME', 'Laser Printer (Color, Duplex)', 48039),
#  (1273824, 'Gigabux', 'UPS 2500 Watt (rackmount)', 47879),
#  (1273825, 'Bigdeal', 'UPS 2500 Watt (rackmount)', 47679),
#  (1274409, 'Tyrell', '36" Wide Screen TV', 47669),
#  (1274457, 'McDowell', 'Digital Video Recorder (1.5 TB)', 47449),
#  (1274611, 'United Digistuff', '173 GB SAS Disk', 47419),
#  (1274458, 'McDowell', 'Digital Video Recorder (1.5 TB)', 47309),
#  (1274575, 'McDowell', 'Laser Printer (Color, Duplex)', 47229),
#  (1274389, 'ACME', '24" Ultra-Premium LCD Monitor', 46939),
#  (1274104, 'Dorx', 'High-range Premium Speakers', 46699),
#  (1274390, 'Olde-Gray', '24" Ultra-Premium LCD Monitor', 46479),
#  (1274693, 'Lemmon', '8 TB NAS Server', 46179),
#  (1274103, 'ElCheapo', 'High-range Premium Speakers', 45639),
#  (1274408, 'Sprite', '36" Wide Screen TV', 45309),
#  (1274337, 'Yoyodyne', 'Basic Desktop', 44119),
#  (1274338, 'Orion', 'Basic Desktop', 43929),
#  (1274351, 'Orion', 'Tablet PC (10 in. display, 32 GB)', 43869),
#  (1274336, 'Bitmonkey', 'Basic Desktop', 43459),
#  (1274122, 'Wernham', 'Camcorder (Digital)', 43309),
#  (1274407, 'Lemmon', '36" Wide Screen TV', 43129),
#  (1274673, 'Orion', '16 GB USB Flash Drive (Red)', 42999),
#  (1274358, 'Orion', 'Tablet PC (7 in. display, 32 GB)', 42939),
#  (1274353, 'Orion', 'Tablet PC (10 in. display, 32 GB)', 42869),
#  (1274411, 'McDowell', '36" Wide Screen TV', 42859),
#  (1274410, 'Weisenheimer', '36" Wide Screen TV', 42289),
#  (1274352, 'Orion', 'Tablet PC (10 in. display, 32 GB)', 41969),
#  (1274121, 'Artie', 'Camcorder (Digital)', 41939),
#  (1273817, 'Dualcore', 'VR Glove', 41529),
#  (1274357, 'Homertech', 'Tablet PC (7 in. display, 32 GB)', 40989),
#  (1274446, 'ARCAM', 'Gaming Console (WiFi)', 40599),
#  (1274718, 'Bitbucket', '128 GB SSD Disk', 40539),
#  (1274561, 'McDowell', 'Laser Printer (Black-and-White)', 40399),
#  (1274558, 'ACME', 'Laser Printer (Black-and-White)', 40059),
#  (1274454, 'McDowell', 'Digital Video Recorder (1.0 TB)', 39719),
#  (1274445, 'Sprite', 'Gaming Console (WiFi)', 39699),
#  (1274563, 'Tyrell', 'Laser Printer (Black-and-White)', 39689),
#  (1274559, 'McDowell', 'Laser Printer (Black-and-White)', 39579),
#  (1274564, 'McDowell', 'Laser Printer (Black-and-White)', 39559),
#  (1274453, 'Wolfpack', 'Digital Video Recorder (1.0 TB)', 39309),
#  (1274571, 'Tyrell', 'Laser Printer (Color)', 39309),
#  (1274554, 'ACME', 'Laser Printer (Black-and-White)', 39279),
#  (1274555, 'McDowell', 'Laser Printer (Black-and-White)', 39019),
#  (1274354, 'Byteweasel', 'Tablet PC (10 in. display, 16 GB)', 38949),
#  (1274573, 'ACME', 'Laser Printer (Color)', 38849),
#  (1274116, 'ARCAM', 'Digital Camera (Professional)', 38769),
#  (1274719, 'Spindown', '128 GB SSD Disk', 38689),
#  (1274280, 'BDT', '4x2GB DDR3 1333MHz Triple Channel Desktop RAM', 38609),
#  (1274455, 'McDowell', 'Digital Video Recorder (1.0 TB)', 38489),
#  (1274574, 'ACME', 'Laser Printer (Color)', 38459),
#  (1274452, 'Gigabux', 'Digital Video Recorder (1.0 TB)', 38389),
#  (1274560, 'ACME', 'Laser Printer (Black-and-White)', 38319),
#  (1274556, 'Olde-Gray', 'Laser Printer (Black-and-White)', 38189),
#  (1274572, 'Tyrell', 'Laser Printer (Color)', 38059),
#  (1274406, 'Artie', '32" Wide Screen TV', 38019),
#  (1274348, 'Byteweasel', 'Tablet PC (10 in. display, 64 GB)', 37999),
#  (1274557, 'Tyrell', 'Laser Printer (Black-and-White)', 37969),
#  (1274279, 'ACME', '4x2GB DDR3 1333MHz Triple Channel Desktop RAM', 37929),
#  (1274565, 'Olde-Gray', 'Laser Printer (Black-and-White)', 37899),
#  (1274567, 'ACME', 'Laser Printer (Black-and-White)', 37889),
#  (1274566, 'ACME', 'Laser Printer (Black-and-White)', 37839),
#  (1274384, 'ElCheapo', '27" Wide Screen LCD Monitor', 37739),
#  (1274405, 'Argo', '32" Wide Screen TV', 37739),
#  (1274562, 'McDowell', 'Laser Printer (Black-and-White)', 37629),
#  (1274355, 'Orion', 'Tablet PC (10 in. display, 16 GB)', 37449),
#  (1274404, 'Lemmon', '32" Wide Screen TV', 36909),
#  (1274443, 'McDowell', 'Gaming Console', 36599),
#  (1274383, 'Lemmon', '27" Wide Screen LCD Monitor', 36159),
#  (1274382, 'Wernham', '27" Wide Screen LCD Monitor', 36139),
#  (1274385, 'Wernham', '27" Wide Screen LCD Monitor', 36119),
#  (1274403, 'Lemmon', '32" Wide Screen TV', 36069),
#  (1274402, 'Wernham', '32" Wide Screen TV', 36059),
#  (1274356, 'Orion', 'Tablet PC (10 in. display, 16 GB, WiFi-only)', 35889),
#  (1274442, 'Sprite', 'Gaming Console', 35649),
#  (1274444, 'Weisenheimer', 'Gaming Console', 35559),
#  (1274450, 'Wolfpack', 'Digital Video Recorder (750 GB)', 35229),
#  (1274361, 'Homertech', 'Tablet PC (7 in. display, 16 GB)', 35219),
#  (1274362, 'Electrosaurus', 'Tablet PC (7 in. display, 16 GB)', 35019),
#  (1274451, 'Lemmon', 'Digital Video Recorder (750 GB)', 34449),
#  (1274600, 'Byteweasel', 'Office Suite (Basic Edition)', 33989),
#  (1274359, 'United Digistuff', 'Tablet PC (7 in. display, 16 GB, WiFi-only)', 32589),
#  (1274360, 'Olde-Gray', 'Tablet PC (7 in. display, 16 GB, WiFi-only)', 32589),
#  (1274449, 'Argo', 'Digital Video Recorder (750 GB)', 32439),
#  (1274601, 'Bitbucket', 'Office Suite (Basic Edition)', 32149),
#  (1274119, 'McDowell', 'Camcorder (Betamax)', 31749),
#  (1274363, 'BuckLogix', 'Tablet PC (7 in. display, 8 GB)', 31439),
#  (1274120, 'Artie', 'Camcorder (Betamax)', 31219),
#  (1274692, 'Megachango', '4 TB NAS Server', 31159),
#  (1274118, 'ARCAM', 'Camcorder (VHS)', 30999),
#  (1274346, 'Olde-Gray', 'Economy Netbook', 30639),
#  (1274364, 'Sparky', 'Tablet PC (7 in. display, 8 GB, WiFI-only)', 30359),
#  (1274447, 'Tyrell', 'Digital Video Recorder (500 GB)', 30079),
#  (1274691, 'Wolfpack', '4 TB NAS Server', 29799),
#  (1274063, 'ElCheapo', 'Stereo Component Turntable', 29759),
#  (1274538, 'ACME', 'Dot Matrix Printer', 29719),
#  (1274392, 'Sprite', '24" LED Backlit Monitor', 29619),
#  (1274393, 'Olde-Gray', '24" LED Backlit Monitor', 29579),
#  (1274117, 'Argo', 'Camcorder (VHS)', 29439),
#  (1274064, 'Dualcore', 'Stereo Component Turntable', 29419),
#  (1274347, 'Homertech', 'Economy Netbook', 29249),
#  (1274448, 'Lemmon', 'Digital Video Recorder (500 GB)', 29089),
#  (1274584, 'McDowell', 'Scanner', 28349),
#  (1274223, 'ElCheapo', '3.8GHz CPU', 28319),
#  (1274580, 'McDowell', 'Scanner', 28309),
#  (1274098, 'ElCheapo', 'All-weather Speakers', 28169),
#  (1274224, 'Orion', '3.8GHz CPU', 28079),
#  (1274585, 'Olde-Gray', 'All-in-one Print/Fax/Scan/Copy', 28059),
#  (1274495, 'Wolfpack', 'Firewall', 28039),
#  (1274582, 'Olde-Gray', 'Scanner', 27979),
#  (1274496, 'BDT', 'Firewall', 27909),
#  (1274539, 'Olde-Gray', 'Daisy Wheel Printer', 27839),
#  (1274225, 'ACME', '3.8GHz CPU', 27829),
#  (1274401, 'Artie', '27" Wide Screen TV', 27829),
#  (1274579, 'ACME', 'Scanner', 27769),
#  (1274586, 'McDowell', 'All-in-one Print/Fax/Scan/Copy', 27729),
#  (1274399, 'Chestnut', '27" Wide Screen TV', 27589),
#  (1274588, 'Olde-Gray', 'All-in-one Print/Fax/Scan/Copy', 27569),
#  (1274581, 'Tyrell', 'Scanner', 27549),
#  (1274587, 'Olde-Gray', 'All-in-one Print/Fax/Scan/Copy', 27379),
#  (1274583, 'Olde-Gray', 'Scanner', 27349),
#  (1274493, 'TPS', 'Firewall', 27339),
#  (1274300, 'Orion', 'Server Motherboard', 27319),
#  (1274494, 'Foocorp', 'Firewall', 27029),
#  (1274299, 'TPS', 'Server Motherboard', 26919),
#  (1274093, 'Wernham', 'MP3 Player (64 GB internal memory)', 26819),
#  (1274092, 'Lemmon', 'MP3 Player (64 GB internal memory)', 26469),
#  (1274400, 'Sprite', '27" Wide Screen TV', 25799),
#  (1274391, 'Ultramegaco', '21" LED Backlit Monitor', 24859),
#  (1274398, 'Electrosaurus', '24" Wide Screen TV', 24139),
#  (1274553, 'Tyrell', 'Inkjet Photo Printer', 24129),
#  (1274397, 'Gigabux', '24" Wide Screen TV', 23899),
#  (1274381, 'Wernham', '24" Wide Screen LCD Monitor', 23809),
#  (1274375, 'ElCheapo', '24" Wide Screen LCD Monitor', 23639),
#  (1274379, 'ElCheapo', '24" Wide Screen LCD Monitor', 23539),
#  (1274552, 'McDowell', 'Inkjet Photo Printer', 23419),
#  (1274590, 'ACME', 'All-in-one Print/Scan/Copy', 23369),
#  (1274599, 'Bytefortress', 'Office Suite (Home Edition)', 23259),
#  (1274589, 'McDowell', 'All-in-one Print/Scan/Copy', 23029),
#  (1274497, 'Homertech', 'VPN Appliance (16 Client license)', 23019),
#  (1274376, 'Ultramegaco', '24" Wide Screen LCD Monitor', 22909),
#  (1274714, 'Megachango', '64 GB SSD Disk', 22829),
#  (1274380, 'Dualcore', '24" Wide Screen LCD Monitor', 22719),
#  (1274498, 'Dualcore', 'VPN Appliance (16 Client license)', 22699),
#  (1274378, 'Olde-Gray', '24" Wide Screen LCD Monitor', 22579),
#  (1274715, 'Megachango', '64 GB SSD Disk', 22479),
#  (1274222, 'Overtop', '3.6GHz CPU', 22289),
#  (1274221, 'ElCheapo', '3.6GHz CPU', 22199),
#  (1274377, 'Wernham', '24" Wide Screen LCD Monitor', 22169),
#  (1274717, 'United Digistuff', '64 GB SSD Disk', 22129),
#  (1274713, 'Tortoise', '64 GB SSD Disk', 22109),
#  (1274220, 'Electrosaurus', '3.6GHz CPU', 22049),
#  (1274716, 'ACME', '64 GB SSD Disk', 21929),
#  (1274712, 'Krustybitz', '64 GB SSD Disk', 21619),
#  (1274711, 'DevNull', '64 GB SSD Disk', 21509),
#  (1274278, 'Ultramegaco', '2x2GB DDR3 1600MHz Desktop RAM', 21179),
#  (1274277, 'XYZ', '2x2GB DDR3 1600MHz Desktop RAM', 21029),
#  (1274276, 'ACME', '2x2GB DDR3 1600MHz Desktop RAM', 20969),
#  (1274275, 'XYZ', '2x2GB DDR3 1600MHz Desktop RAM', 20789),
#  (1274115, 'Artie', 'Digital Camera (Pro-Am)', 20759),
#  (1274274, 'TPS', '2x2GB DDR3 1600MHz Desktop RAM', 20669),
#  (1274060, 'Lemmon', 'Stereo Component CD Player', 20229),
#  (1274114, 'McDowell', 'Digital Camera (Pro-Am)', 20119),
#  (1274061, 'Chatter Audio', 'Stereo Component CD Player', 19869),
#  (1273826, 'McDowell', 'UPS 1500 Watt', 19629),
#  (1274642, 'Tortoise', '2.0 TB SATA3 Disk (10K RPM)', 19429),
#  (1274644, 'Tortoise', '2.0 TB SATA3 Disk (10K RPM)', 19319),
#  (1274643, 'ACME', '2.0 TB SATA3 Disk (10K RPM)', 19219),
#  (1274062, 'Weisenheimer', 'Stereo Component CD Player', 19179),
#  (1274094, 'Weisenheimer', 'Subwoofer (15 in.)', 19059),
#  (1274293, 'Sparky', '2GB DDR2 800MHz Laptop RAM', 18989),
#  (1274273, 'SuperGamer', '2GB Super Gamer Graphics Card', 18949),
#  (1274536, 'Dualcore', 'Ethernet NIC (10 Gigabit)', 18939),
#  (1274272, 'XYZ', '2GB Super Gamer Graphics Card', 18899),
#  (1274648, 'Dorx', '3.0 TB SATA3 Disk', 18879),
#  (1274647, 'Bitbucket', '3.0 TB SATA3 Disk', 18799),
#  (1274645, 'Megachango', '3.0 TB SATA3 Disk', 18789),
#  (1274067, 'Wernham', 'Stereo Component Streaming Media Player', 18759),
#  (1274090, 'Chatter Audio', 'MP3 Player (32 GB internal memory)', 18669),
#  (1274549, 'Tyrell', 'Inkjet Printer', 18579),
#  (1274541, 'Tyrell', 'Inkjet Printer', 18539),
#  (1274105, 'Chatter Audio', 'Microphone (model U47)', 18439),
#  (1274545, 'Tyrell', 'Inkjet Printer', 18439),
#  (1274649, 'DevNull', '3.0 TB SATA3 Disk', 18379),
#  (1274537, 'Foocorp', 'Ethernet NIC (10 Gigabit)', 18319),
#  (1274646, 'Wolfpack', '3.0 TB SATA3 Disk', 18229),
#  (1274294, 'Orion', 'Professional DDR3 Motherboard', 18189),
#  (1274544, 'ACME', 'Inkjet Printer', 18169),
#  (1274219, 'Dualcore', '3.4GHz CPU', 18059),
#  (1274372, 'Sprite', '22" Wide Screen LCD Monitor', 18039),
#  (1274091, 'Chatter Audio', 'MP3 Player (32 GB internal memory)', 17999),
#  (1274550, 'Tyrell', 'Inkjet Printer', 17999),
#  (1274371, 'ACME', '22" Wide Screen LCD Monitor', 17989),
#  (1274068, 'Weisenheimer', 'Stereo Component Streaming Media Player', 17969),
#  (1274295, 'Megachango', 'Professional DDR3 Motherboard', 17939),
#  (1274217, 'United Digistuff', '3.4GHz CPU', 17919),
#  (1273828, 'Bigdeal', 'UPS 1500 Watt', 17909),
#  (1274551, 'McDowell', 'Inkjet Printer', 17839),
#  (1274370, 'Wernham', '22" Wide Screen LCD Monitor', 17829),
#  (1274548, 'Tyrell', 'Inkjet Printer', 17799),
#  (1274209, 'BuckLogix', 'XTREME Motherboard', 17789),
#  (1274218, 'TPS', '3.4GHz CPU', 17769),
#  (1274374, 'Argo', '22" Wide Screen LCD Monitor', 17769),
#  (1274296, 'ACME', 'Professional DDR3 Motherboard', 17759),
#  (1274542, 'McDowell', 'Inkjet Printer', 17729),
#  (1274373, 'Argo', '22" Wide Screen LCD Monitor', 17719),
#  (1274546, 'McDowell', 'Inkjet Printer', 17699),
#  (1274543, 'Tyrell', 'Inkjet Printer', 17689),
#  (1274089, 'ElCheapo', 'MP3 Player (32 GB internal memory)', 17669),
#  (1274547, 'Olde-Gray', 'Inkjet Printer', 17669),
#  (1274540, 'McDowell', 'Inkjet Printer', 17649),
#  (1273827, 'DevNull', 'UPS 1500 Watt', 17289),
#  (1274097, 'Terrapin Sands', 'Subwoofer (12 in.)', 17269),
#  (1274689, 'Dorx', '1 TB NAS Server', 16769),
#  (1274095, 'Lemmon', 'Subwoofer (12 in.)', 16509),
#  (1274096, 'Weisenheimer', 'Subwoofer (12 in.)', 16469),
#  (1273830, 'Duff', 'UPS 1200 Watt', 16249),
#  (1274210, 'Sparky', 'PERTURB Motherboard', 16239),
#  (1274214, 'Sparky', '3.2GHz CPU', 16239),
#  (1274690, 'Orion', '1 TB NAS Server', 16239),
#  (1274216, 'Dualcore', '3.2GHz CPU', 16229),
#  (1274215, 'ACME', '3.2GHz CPU', 15739),
#  (1274627, 'Tortoise', '1.0 TB SATA3 Disk (10K RPM)', 15619),
#  (1274707, 'Bitbucket', '32 GB SSD Disk', 15599),
#  (1274369, 'ElCheapo', '20" Wide Screen LCD Monitor', 15559),
#  (1273829, 'McDowell', 'UPS 1200 Watt', 15249),
#  (1274292, 'Megachango', '2GB DDR2 667 RAM', 15239),
#  (1274626, 'United Digistuff', '1.0 TB SATA3 Disk (10K RPM)', 15219),
#  (1274710, 'ElCheapo', '32 GB SSD Disk', 15129),
#  (1274368, 'Lemmon', '20" Wide Screen LCD Monitor', 15119),
#  (1273831, 'ACME', 'UPS 1000 Watt', 15069),
#  (1274291, 'BuckLogix', '2GB DDR2 667 RAM', 15029),
#  (1274628, 'ACME', '1.0 TB SATA3 Disk (10K RPM)', 15029),
#  (1274637, 'Byteweasel', '2.0 TB SATA3 Disk', 14939),
#  (1274367, 'Olde-Gray', '20" Wide Screen LCD Monitor', 14909),
#  (1274708, 'Homertech', '32 GB SSD Disk', 14789),
#  (1274640, 'ACME', '2.0 TB SATA3 Disk', 14759),
#  (1274709, 'Krustybitz', '32 GB SSD Disk', 14699),
#  (1274638, 'Dorx', '2.0 TB SATA3 Disk', 14469),
#  (1274636, 'Wolfpack', '2.0 TB SATA3 Disk', 14409),
#  (1274639, 'DevNull', '2.0 TB SATA3 Disk', 14289),
#  (1274641, 'Tortoise', '2.0 TB SATA3 Disk', 14289),
#  (1273835, 'TPS', 'UPS 800 Watt', 13799),
#  (1273792, 'Chestnut', 'Keyboard (wireless, with nub)', 13709),
#  (1273791, 'Ultramegaco', 'Keyboard (wireless, with trackball)', 13689),
#  (1274437, 'Lemmon', 'Video Cassette Recorder', 13669),
#  (1274087, 'Lemmon', 'MP3 Player (16 GB internal memory)', 13619),
#  (1274598, 'Byteweasel', 'Office Suite (Student Edition)', 13519),
#  (1274086, 'Weisenheimer', 'MP3 Player (16 GB internal memory)', 13429),
#  (1274633, 'Dualcore', '1.5 TB SATA3 Disk', 13419),
#  (1274365, 'Sprite', '19" Wide Screen LCD Monitor', 13389),
#  (1274366, 'Ultramegaco', '19" Wide Screen LCD Monitor', 13359),
#  (1274629, 'Bitbucket', '1.5 TB SATA3 Disk', 13319),
#  (1274433, 'Wernham', 'Blu-Ray Player', 13299),
#  (1274434, 'Artie', 'Blu-Ray Player', 13269),
#  (1274464, 'Bigdeal', 'Dual Band Wireless Range Extender', 13219),
#  (1274632, 'Homertech', '1.5 TB SATA3 Disk', 13219),
#  (1273833, 'Gigabux', 'UPS 1000 Watt', 13209),
#  (1274289, 'SuperGamer', '1GB DDR2 800 Desktop RAM', 13199),
#  (1274107, 'Wernham', 'Wireless Microphone', 13189),
#  (1274108, 'Terrapin Sands', 'Wireless Microphone', 13179),
#  (1273832, 'Megachango', 'UPS 1000 Watt', 13169),
#  (1274281, 'ElCheapo', '2x1GB Value DDR2 - 667 RAM', 13169),
#  (1274290, 'BDT', '1GB DDR2 800 Desktop RAM', 13169),
#  (1274523, 'Duff', 'Network Switch (Gigabit, 24-port)', 13159),
#  (1274213, 'Electrosaurus', '3.0GHz CPU', 13129),
#  (1273836, 'Tyrell', 'UPS 800 Watt', 13119),
#  (1274083, 'Dualcore', 'MP3 Player (16 GB internal memory)', 13119),
#  (1274082, 'ElCheapo', 'MP3 Player (16 GB internal memory)', 13099),
#  (1274204, 'Electrosaurus', 'Full Tower Computer Case', 13089),
#  (1274282, 'Ultramegaco', '2x1GB Value DDR2 - 667 RAM', 13079),
#  (1274635, 'Dualcore', '1.5 TB SATA3 Disk', 13059),
#  (1274112, 'Wernham', 'Digital Camera (Basic)', 13049),
#  (1274113, 'ElCheapo', 'Digital Camera (Basic)', 13049),
#  (1274206, 'Electrosaurus', 'Full Tower Computer Case', 13039),
#  (1274436, 'Wernham', 'Video Cassette Recorder', 12959),
#  (1274211, 'Sparky', 'DISGRUNT Motherboard', 12939),
#  (1274521, 'Wolfpack', 'Network Switch (Gigabit, 24-port)', 12929),
#  (1274085, 'Lemmon', 'MP3 Player (16 GB internal memory)', 12899),
#  (1274212, 'SuperGamer', '3.0GHz CPU', 12899),
#  (1274705, 'Bitbucket', '750 GB Portable External USB 3.0 Disk', 12889),
#  (1274207, 'Ultramegaco', 'Full Tower Computer Case', 12879),
#  (1274084, 'Weisenheimer', 'MP3 Player (16 GB internal memory)', 12859),
#  (1274208, 'XYZ', 'Full Tower Computer Case', 12849),
#  (1274106, 'Weisenheimer', 'Wireless Microphone', 12839),
#  (1274205, 'Megachango', 'Full Tower Computer Case', 12829),
#  (1274080, 'Dorx', 'MP3 Player (16 GB internal memory)', 12819),
#  (1274520, 'Duff', 'Network Switch (Gigabit, 24-port)', 12789),
#  (1274439, 'Whiteacre', 'Video Cassette Recorder (Betamax format)', 12729),
#  (1274522, 'BuckLogix', 'Network Switch (Gigabit, 24-port)', 12729),
#  (1274706, 'Krustybitz', '750 GB Portable External USB 3.0 Disk', 12729),
#  (1274111, 'ElCheapo', 'Digital Camera (Basic)', 12649),
#  (1274079, 'Chatter Audio', 'MP3 Player (16 GB internal memory)', 12619),
#  (1274630, 'United Digistuff', '1.5 TB SATA3 Disk', 12619),
#  (1274634, 'Dualcore', '1.5 TB SATA3 Disk', 12619),
#  (1274088, 'Chatter Audio', 'MP3 Player (16 GB internal memory)', 12609),
#  (1274463, 'Bigdeal', 'Dual Band Wireless Range Extender', 12559),
#  (1274438, 'Sprite', 'Video Cassette Recorder (Betamax format)', 12549),
#  (1274078, 'Terrapin Sands', 'MP3 Player (16 GB internal memory)', 12539),
#  (1274435, 'Chestnut', 'Blu-Ray Player', 12529),
#  (1273834, 'Megachango', 'UPS 800 Watt', 12429),
#  (1274704, 'Dualcore', '750 GB Portable External USB 3.0 Disk', 12409),
#  (1274081, 'ElCheapo', 'MP3 Player (16 GB internal memory)', 12369),
#  (1274631, 'United Digistuff', '1.5 TB SATA3 Disk', 12369),
#  (1274622, 'Megachango', '1.0 TB SATA3 Disk', 11159),
#  (1274625, 'Spindown', '1.0 TB SATA3 Disk', 11089),
#  (1274441, 'Wolfpack', 'LaserDisc Player', 10919),
#  (1274624, 'Krustybitz', '1.0 TB SATA3 Disk', 10749),
#  (1274623, 'Lemmon', '1.0 TB SATA3 Disk', 10679),
#  (1274440, 'Wolfpack', 'LaserDisc Player', 10639),
#  (1274621, 'Spindown', '1.0 TB SATA3 Disk', 10509),
#  (1274702, 'ElCheapo', '500 GB Portable External USB 3.0 Disk', 10489),
#  (1274703, 'Megachango', '500 GB Portable External USB 3.0 Disk', 10489),
#  (1274619, 'United Digistuff', '750 GB SATA3 Disk', 10469),
#  (1274617, 'Krustybitz', '750 GB SATA3 Disk', 10399),
#  (1274076, 'Terrapin Sands', 'MP3 Player (8 GB internal memory)', 10349),
#  (1274472, 'Wolfpack', 'Wireless N Modem Router', 10309),
#  (1274065, 'Wernham', 'Stereo Component Cassette Player', 10229),
#  (1274618, 'Krustybitz', '750 GB SATA3 Disk', 10209),
#  (1274754, 'Wolfpack', '64 GB Micro SD', 10209),
#  (1274468, 'TPS', 'ADSL2 Modem + Wireless G Router', 10179),
#  (1274075, 'Terrapin Sands', 'MP3 Player (8 GB internal memory)', 10169),
#  (1274248, 'ElCheapo', 'TV Tuner Card w/HDMI Output (PCI)', 10159),
#  (1274247, 'TPS', 'TV Tuner Card w/HDMI Output (PCI)', 10149),
#  (1274249, 'XYZ', 'TV Tuner Card w/HDMI Output (PCI)', 10089),
#  (1274469, 'Texi', 'ADSL2 Modem + Wireless G Router', 10059),
#  (1274288, 'SuperGamer', '1GB DDR2 667 Laptop RAM', 10019),
#  (1274267, 'XYZ', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 10009),
#  (1274287, 'Overtop', '1GB DDR2 667 Laptop RAM', 10009),
#  (1274266, 'Sparky', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 9959),
#  (1274268, 'Electrosaurus', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 9939),
#  (1274269, 'Ultramegaco', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 9939),
#  (1274700, 'Megachango', '500 GB Portable External USB 3.0 Disk', 9929),
#  (1274265, 'Electrosaurus', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 9919),
#  (1274620, 'Orion', '750 GB SATA3 Disk', 9919),
#  (1274286, 'TPS', '1GB DDR2 667 Laptop RAM', 9909),
#  (1274197, 'Overtop', 'A3000 Gaming Cabinet', 9869),
#  (1274473, 'Dualcore', 'Wireless N Modem Router', 9869),
#  (1274752, 'Dorx', '64 GB Micro SD', 9859),
#  (1274474, 'Wolfpack', 'Wireless N Modem Router', 9839),
#  (1274270, 'TPS', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 9829),
#  (1274753, 'Homertech', '64 GB Micro SD', 9809),
#  (1274271, 'Sparky', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 9769),
#  (1274074, 'Terrapin Sands', 'MP3 Player (8 GB internal memory)', 9739),
#  (1274077, 'Dualcore', 'MP3 Player (8 GB internal memory)', 9669),
#  (1274701, 'Wolfpack', '500 GB Portable External USB 3.0 Disk', 9539),
#  (1273788, 'Bigdeal', 'Keyboard (gamer PC104)', 9469),
#  (1274688, 'Krustybitz', '64 GB USB Flash Drive', 9339),
#  (1274687, 'Byteweasel', '64 GB USB Flash Drive', 9169),
#  (1274616, 'Homertech', '500 GB SATA3 Disk', 9159),
#  (1274466, 'Dualcore', 'ADSL Modem + Wireless N Router', 9139),
#  (1274100, 'ElCheapo', 'Amplified Multimedia Speakers', 9039),
#  (1274465, 'TPS', 'ADSL Modem + Wireless N Router', 8989),
#  (1274615, 'Orion', '500 GB SATA3 Disk', 8989),
#  (1274305, 'Electrosaurus', 'Soundcard (Premium Multimedia)', 8979),
#  (1274467, 'Duff', 'ADSL Modem + Wireless N Router', 8969),
#  (1274685, 'Megachango', '64 GB USB Flash Drive', 8959),
#  (1274109, 'Dorx', 'Digital Recorder (pocket size)', 8899),
#  (1274304, 'ACME', 'Soundcard (Premium Multimedia)', 8889),
#  (1274102, 'Terrapin Sands', 'Amplified Multimedia Speakers', 8839),
#  (1274099, 'Weisenheimer', 'Amplified Multimedia Speakers', 8799),
#  (1274684, 'Megachango', '64 GB USB Flash Drive', 8799),
#  (1274110, 'Lemmon', 'Digital Recorder (pocket size)', 8749),
#  (1274487, 'Wolfpack', 'Wireless G Access Point', 8749),
#  (1274605, 'United Digistuff', '60 GB PATA Disk', 8719),
#  (1273838, 'DevNull', 'UPS 500 Watt', 8699),
#  (1274486, 'Foocorp', 'Wireless G Access Point', 8669),
#  (1274686, 'Dorx', '64 GB USB Flash Drive', 8669),
#  (1273789, 'McDowell', 'Keyboard (gamer PC104)', 8659),
#  (1274488, 'Texi', 'Wireless G Access Point', 8599),
#  (1274614, 'United Digistuff', '500 GB SATA3 Disk', 8579),
#  (1274101, 'Terrapin Sands', 'Amplified Multimedia Speakers', 8559),
#  (1273837, 'Tyrell', 'UPS 500 Watt', 8489),
#  (1274462, 'Whiteacre', '3D Digital TV Glasses', 8469),
#  (1273790, 'Tyrell', 'Keyboard (gamer PC104)', 8389),
#  (1274461, 'Wernham', '3D Digital TV Glasses', 8369),
#  (1274071, 'ElCheapo', 'MP3 Player (4 GB internal memory)', 8299),
#  (1274699, 'DevNull', '500 GB Portable External USB 2.0 Disk', 8299),
#  (1274475, 'Dualcore', 'Wireless G Router', 8249),
#  (1274476, 'Dualcore', 'Wireless G Router', 8249),
#  (1274606, 'DevNull', '9.1 GB SCSI Disk', 8229),
#  (1274194, 'BuckLogix', 'AT Computer Case', 8119),
#  (1274039, 'Lemmon', 'Gamer Headphone', 8109),
#  (1274176, 'Megachango', 'Beige 8X BD-ROM 16X DVD-ROM', 8109),
#  (1274283, 'BuckLogix', '1GB DDR 400 Desktop RAM', 8109),
#  (1274285, 'TPS', '1GB DDR 400 Desktop RAM', 8099),
#  (1274173, 'Ultramegaco', 'Black 8X BD-ROM 16X DVD-ROM', 8059),
#  (1274175, 'Megachango', 'Beige 8X BD-ROM 16X DVD-ROM', 8059),
#  (1274073, 'Weisenheimer', 'MP3 Player (4 GB internal memory)', 8039),
#  (1274199, 'SuperGamer', 'Mid Tower Computer Case', 8029),
#  (1274297, 'XYZ', 'Desktop Motherboard', 8029),
#  (1274201, 'BDT', 'Mid Tower Computer Case', 8009),
#  (1274519, 'Duff', 'Network Switch (Gigabit, 16-port)', 7989),
#  (1274262, 'ElCheapo', '512MB PCI-X Graphics Card (OEM)', 7979),
#  (1274203, 'Orion', 'Mid Tower Computer Case', 7959),
#  (1274259, 'Ultramegaco', '512MB PCI-X Graphics Card (OEM)', 7959),
#  (1274200, 'BuckLogix', 'Mid Tower Computer Case', 7949),
#  (1274242, 'United Digistuff', 'SCSI Expansion Card (PCI)', 7939),
#  (1274284, 'Sparky', '1GB DDR 400 Desktop RAM', 7939),
#  (1274261, 'Megachango', '512MB PCI-X Graphics Card (OEM)', 7929),
#  (1274298, 'Overtop', 'Desktop Motherboard', 7929),
#  (1274193, 'ElCheapo', 'AT Computer Case', 7919),
#  (1274258, 'Electrosaurus', '512MB PCI-X Graphics Card (OEM)', 7919),
#  (1274263, 'BuckLogix', '512MB PCI-X Graphics Card (OEM)', 7919),
#  (1274174, 'Dualcore', 'Black 8X BD-ROM 16X DVD-ROM', 7909),
#  (1274243, 'ElCheapo', 'SCSI Expansion Card (PCI)', 7909),
#  (1274202, 'BuckLogix', 'Mid Tower Computer Case', 7899),
#  (1274244, 'United Digistuff', 'SCSI Expansion Card (PCI)', 7889),
#  (1274516, 'Wolfpack', 'Network Switch (Gigabit, 16-port)', 7889),
#  (1274198, 'XYZ', 'Mid Tower Computer Case', 7879),
#  (1274264, 'Sparky', '512MB PCI-X Graphics Card (OEM)', 7869),
#  (1274517, 'BDT', 'Network Switch (Gigabit, 16-port)', 7869),
#  (1273806, 'TPS', 'Trackball (wireless)', 7859),
#  (1274260, 'BuckLogix', '512MB PCI-X Graphics Card (OEM)', 7819),
#  (1274515, 'Wolfpack', 'Network Switch (Gigabit, 16-port)', 7799),
#  (1274038, 'Lemmon', 'Gamer Headphone', 7789),
#  (1274072, 'Dualcore', 'MP3 Player (4 GB internal memory)', 7699),
#  (1274037, 'ElCheapo', 'Gamer Headphone', 7669),
#  (1274518, 'BDT', 'Network Switch (Gigabit, 16-port)', 7669),
#  (1274698, 'ACME', '500 GB Portable External USB 2.0 Disk', 7609),
#  (1274460, 'Electrosaurus', '3D Digital TV Glasses', 7599),
#  (1273807, 'TPS', 'Trackball (wireless)', 7549),
#  (1273875, 'Ultramegaco', 'Extension cord (50 ft., outdoor)', 7329),
#  (1274751, 'Krustybitz', '32 GB Micro SD (High Performance)', 7219),
#  (1274471, 'Homertech', 'Basic Wireless Modem Router', 7109),
#  (1274238, 'Sparky', 'Fireware 800 Card (PCI)', 7089),
#  (1274240, 'Ultramegaco', 'Fireware 800 Card (PCI)', 7089),
#  (1274750, 'Megachango', '32 GB Micro SD (High Performance)', 7089),
#  (1274512, 'XYZ', 'Network Switch (Gigabit, 8-port)', 7029),
#  (1273876, 'McDowell', 'Extension cord (50 ft., outdoor)', 7019),
#  (1273688, 'ElCheapo', 'Mobile Bluetooth Keyboard and Stand for Tablets', 7009),
#  (1274241, 'BDT', 'Fireware 800 Card (PCI)', 6999),
#  (1274481, 'Bigdeal', 'Wireless N Router', 6959),
#  (1274239, 'ACME', 'Fireware 800 Card (PCI)', 6929),
#  (1274682, 'Tortoise', '32 GB USB Flash Drive (High Performance)', 6929),
#  (1274066, 'Dualcore', 'Stereo Component 8-Track Player', 6919),
#  (1274683, 'Megachango', '32 GB USB Flash Drive (High Performance)', 6919),
#  (1274514, 'Dualcore', 'Network Switch (Gigabit, 8-port)', 6899),
#  (1274480, 'Dualcore', 'Wireless N Router', 6889),
#  (1274492, 'Foocorp', 'DSL Modem', 6879),
#  (1274470, 'TPS', 'Basic Wireless Modem Router', 6869),
#  (1274490, 'Texi', 'Cable Modem', 6829),
#  (1274491, 'Texi', 'DSL Modem', 6779),
#  (1274484, 'Wolfpack', 'Wireless N USB Adapter', 6739),
#  (1274489, 'BDT', 'Cable Modem', 6639),
#  (1274513, 'Duff', 'Network Switch (Gigabit, 8-port)', 6639),
#  (1274483, 'Homertech', 'Wireless N USB Adapter', 6629),
#  (1274482, 'Dualcore', 'Wireless N USB Adapter', 6559),
#  (1273726, 'Chestnut', '8-cell Battery', 6549),
#  (1273681, 'XYZ', 'High Speed HDMI Cable (72 in.)', 6519),
#  (1274485, 'Duff', 'Wireless N USB Adapter', 6489),
#  (1273725, 'Megachango', '8-cell Battery', 6409),
#  (1274432, 'Whiteacre', 'DVD Player', 6369),
#  (1274604, 'Krustybitz', '20 GB PATA Disk', 6219),
#  (1274677, 'Homertech', '32 GB USB Flash Drive', 6199),
#  (1274533, 'BDT', 'Ethernet NIC (Gigabit)', 6179),
#  (1274529, 'Dualcore', 'Ethernet NIC (Gigabit)', 6139),
#  (1274534, 'BuckLogix', 'Ethernet NIC (Gigabit)', 6139),
#  (1274192, 'Electrosaurus', 'ATX Computer Case', 6099),
#  (1274747, 'DevNull', '32 GB Micro SD', 6059),
#  (1274186, 'ACME', 'ATX Computer Case', 6049),
#  (1274190, 'United Digistuff', 'ATX Computer Case', 6049),
#  (1274185, 'Ultramegaco', 'ATX Computer Case', 6039),
#  (1274188, 'ElCheapo', 'ATX Computer Case', 6039),
#  (1274530, 'Homertech', 'Ethernet NIC (Gigabit)', 6039),
#  (1274532, 'Foocorp', 'Ethernet NIC (Gigabit)', 6039),
#  (1274189, 'Megachango', 'ATX Computer Case', 6009),
#  (1274748, 'Lemmon', '32 GB Micro SD', 6009),
#  (1274749, 'United Digistuff', '32 GB Micro SD', 5989),
#  (1274531, 'TPS', 'Ethernet NIC (Gigabit)', 5979),
#  (1274255, 'Sparky', '128MB AGP Graphics Card', 5939),
#  (1274187, 'ElCheapo', 'ATX Computer Case', 5929),
#  (1274528, 'BuckLogix', 'Ethernet NIC (Gigabit)', 5929),
#  (1274191, 'Orion', 'ATX Computer Case', 5909),
#  (1274430, 'Tyrell', 'DVD Player', 5909),
#  (1274535, 'Homertech', 'Ethernet NIC (Gigabit)', 5909),
#  (1274431, 'Whiteacre', 'DVD Player', 5899),
#  (1274680, 'Lemmon', '32 GB USB Flash Drive', 5869),
#  (1274479, 'BDT', 'Wireless G USB Adapter', 5859),
#  (1274745, 'ACME', '16 GB Micro SD (High Performance)', 5849),
#  (1273680, 'Dualcore', 'High Speed HDMI Cable (72 in.)', 5839),
#  (1274478, 'Homertech', 'Wireless G USB Adapter', 5839),
#  (1274678, 'Tortoise', '32 GB USB Flash Drive', 5839),
#  (1274256, 'Electrosaurus', '128MB AGP Graphics Card', 5829),
#  (1274257, 'ElCheapo', '128MB AGP Graphics Card', 5819),
#  (1274681, 'Krustybitz', '32 GB USB Flash Drive', 5779),
#  (1273724, 'XYZ', '8-cell Battery', 5769),
#  (1274042, 'Chatter Audio', 'Multimedia Headset', 5739),
#  (1274676, 'Dorx', '32 GB USB Flash Drive', 5639),
#  (1274679, 'Megachango', '32 GB USB Flash Drive', 5629),
#  (1274746, 'DevNull', '16 GB Micro SD (High Performance)', 5619),
#  (1274044, 'Dualcore', 'Multimedia Headset', 5609),
#  (1274477, 'Texi', 'Wireless G USB Adapter', 5609),
#  (1274045, 'Chatter Audio', 'Multimedia Headset', 5529),
#  (1274043, 'Terrapin Sands', 'Multimedia Headset', 5519),
#  (1273874, 'ACME', 'Extension cord (20 ft., outdoor)', 5439),
#  (1273679, 'XYZ', 'High Speed HDMI Cable (60 in.)', 5369),
#  (1274603, 'Dorx', '6 GB IDE Disk', 5209),
#  (1274046, 'Wernham', 'Multi-Performance PC Headset', 5179),
#  (1273804, 'ACME', 'Trackball', 5159),
#  (1274047, 'Dualcore', 'Multi-Performance PC Headset', 5129),
#  (1274048, 'Lemmon', 'DSP PC Headset', 5119),
#  (1273678, 'Ultramegaco', 'High Speed HDMI Cable (60 in.)', 5049),
#  (1273873, 'Dualcore', 'Extension cord (20 ft., outdoor)', 5049),
#  (1274237, 'BDT', 'Fireware 400 Card (PCI)', 5019),
#  (1273692, 'XYZ', 'Case for Notebook Computer', 5009)]

# %% [markdown]
# You can try any other price point to see the difference and also try sorting the data in ascending order using the ASC keyword in place of DESC in the query.

# %% [markdown]
# ## Example 6: Ordering Records by Multiple Columns
#
# Now, retrieve customers records from the state 'NY', ordered alphabetically by their city and last name.

# %%
# %%sql
#
# SELECT cust_id, fname, lname, address, city, state, zipcode
# FROM customers
# WHERE state = 'NY'
# ORDER BY city, lname;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 1656 rows affected.
# [(1070724, 'Melissa', 'Blake', '2188 West 17th Street', 'Adams', 'NY', '13605'),
#  (1148684, 'Joan', 'Crum', '1314 North 13th Street', 'Akron', 'NY', '14001'),
#  (1112313, 'Donovan', 'Anderson', '2146 7th Street', 'Albany', 'NY', '12212'),
#  (1014601, 'John', 'Augustine', '1798 Avalon Avenue', 'Albany', 'NY', '12226'),
#  (1002713, 'Martin', 'Beam', '18587 East 5th Street', 'Albany', 'NY', '12238'),
#  (1000730, 'Ralph', 'Benally', '1722 North 7th Street', 'Albany', 'NY', '12227'),
#  (1160817, 'Leah', 'Camacho', '18277 East 2nd Street', 'Albany', 'NY', '12226'),
#  (1085014, 'Brandon', 'Carbone', '20425 North 21st Street', 'Albany', 'NY', '12214'),
#  (1113151, 'Monty', 'Castaneda', '1870 North 13th Street', 'Albany', 'NY', '12243'),
#  (1073267, 'Russell', 'Doyle', '1151 North 5th Street', 'Albany', 'NY', '12243'),
#  (1130420, 'Aaron', 'Egan', '1870 North 13th Street', 'Albany', 'NY', '12243'),
#  (1174988, 'Katherine', 'Fitzgerald', '1990 West 21st Street', 'Albany', 'NY', '12205'),
#  (1115605, 'Colin', 'Green', '1392 West 15th Street', 'Albany', 'NY', '12211'),
#  (1102229, 'Beverly', 'Heckman', '10918 West 11th Street', 'Albany', 'NY', '12255'),
#  (1187706, 'David', 'Hostetter', '1306 Grant Street', 'Albany', 'NY', '12243'),
#  (1191198, 'Louis', 'Kilburn', '1444 East 11th Street', 'Albany', 'NY', '12214'),
#  (1166184, 'Brandon', 'Lankford', '1798 Avalon Avenue', 'Albany', 'NY', '12226'),
#  (1065015, 'Donald', 'Matias', '1392 West 15th Street', 'Albany', 'NY', '12211'),
#  (1155617, 'Samuel', 'Mcclain', '1142 West Grant Road', 'Albany', 'NY', '12244'),
#  (1190299, 'Felipe', 'Mcdonald', '1870 North 13th Street', 'Albany', 'NY', '12243'),
#  (1110050, 'Mary', 'Overton', '12338 East 18th Street', 'Albany', 'NY', '12240'),
#  (1187515, 'Concepcion', 'Painter', '11947 West 19th Street', 'Albany', 'NY', '12250'),
#  (1147699, 'Richard', 'Perry', '21904 East 23rd Street', 'Albany', 'NY', '12243'),
#  (1051156, 'Jeanette', 'Rood', '10918 West 11th Street', 'Albany', 'NY', '12255'),
#  (1101189, 'Marilyn', 'Salazar', '1262 North Wells Lane', 'Albany', 'NY', '12239'),
#  (1138097, 'Wanda', 'Sanchez', '11158 East 20th Street', 'Albany', 'NY', '12205'),
#  (1090616, 'Frank', 'Shaw', '22 West Midland Street', 'Albany', 'NY', '12227'),
#  (1055639, 'Diane', 'Stevenson', '184 East 24th Street', 'Albany', 'NY', '12238'),
#  (1016811, 'Tyler', 'Parnell', '11016 East 24th Street', 'Alplaus', 'NY', '12008'),
#  (1011701, 'Matthew', 'Kibler', '1598 4th Street', 'Altamont', 'NY', '12009'),
#  (1198144, 'Julia', 'Peltier', '1598 4th Street', 'Altamont', 'NY', '12009'),
#  (1020625, 'Michael', 'Hoggard', '1046 East 11th Street', 'Alton', 'NY', '14413'),
#  (1008860, 'Lawrence', 'Macon', '2172 West 4th Street', 'Alton', 'NY', '14413'),
#  (1040530, 'Clarence', 'Moller', '2172 West 4th Street', 'Alton', 'NY', '14413'),
#  (1035459, 'Jordan', 'Dale', '1596 Pierce Road', 'Amenia', 'NY', '12501'),
#  (1033150, 'Cynthia', 'Macleod', '11636 West 23rd Street', 'Amityville', 'NY', '11708'),
#  (1184766, 'Sheryl', 'Magnuson', '1375 Cook Street', 'Amityville', 'NY', '11701'),
#  (1128486, 'Graham', 'Marsh', '11636 West 23rd Street', 'Amityville', 'NY', '11708'),
#  (1138670, 'Keri', 'Mcleod', '1361 West Page Highway', 'Amityville', 'NY', '11701'),
#  (1020715, 'Shawn', 'Casper', '1250 East Baker Drive', 'Ancram', 'NY', '12502'),
#  (1033500, 'Erma', 'Griffin', '1006 Campbell Street', 'Ancram', 'NY', '12502'),
#  (1082092, 'Eric', 'Howell', '1006 Campbell Street', 'Ancram', 'NY', '12502'),
#  (1036668, 'Gloria', 'Quarles', '1250 East Baker Drive', 'Ancram', 'NY', '12502'),
#  (1062461, 'James', 'Rivera', '17392 North 24th Street', 'Annandale On Hudson', 'NY', '12504'),
#  (1177471, 'William', 'Rose', '17392 North 24th Street', 'Annandale On Hudson', 'NY', '12504'),
#  (1063396, 'Laura', 'Tinsley', '1931 East 6th Street', 'Appleton', 'NY', '14008'),
#  (1187561, 'Betty', 'Dyer', '2155 East 21st Street', 'Aquebogue', 'NY', '11931'),
#  (1154701, 'Seth', 'Kelly', '2155 East 21st Street', 'Aquebogue', 'NY', '11931'),
#  (1040192, 'Loretta', 'Brown', '1148 Ridgeline Road', 'Arden', 'NY', '10910'),
#  (1140753, 'Patricia', 'Frost', '1148 Ridgeline Road', 'Arden', 'NY', '10910'),
#  (1077417, 'Billy', 'Kennard', '1148 Ridgeline Road', 'Arden', 'NY', '10910'),
#  (1083175, 'Anthony', 'Ward', '1563 East 1st Street', 'Arden', 'NY', '10910'),
#  (1154839, 'Rodrigo', 'Castaneda', '1426 East Wright Street', 'Ardsley On Hudson', 'NY', '10503'),
#  (1180991, 'Janice', 'Diaz', '1426 East Wright Street', 'Ardsley On Hudson', 'NY', '10503'),
#  (1186966, 'Colby', 'Bryce', '17324 North 16th Street', 'Arverne', 'NY', '11692'),
#  (1077265, 'Miriam', 'Garrison', '1397 Buckingham Street', 'Arverne', 'NY', '11692'),
#  (1113940, 'Elizabeth', 'Rutledge', '2163 West 5th Street', 'Arverne', 'NY', '11692'),
#  (1056181, 'Katie', 'Staton', '1397 Buckingham Street', 'Arverne', 'NY', '11692'),
#  (1027620, 'Margaret', 'Shepard', '2098 East 1st Street', 'Athens', 'NY', '12015'),
#  (1190486, 'Darryl', 'Mueller', '1529 West Grant Road', 'Athol', 'NY', '12810'),
#  (1146346, 'Tonya', 'Magruder', '1748 East 14th Street', 'Athol Springs', 'NY', '14010'),
#  (1070093, 'Lori', 'Garcia', '1505 Airport Road', 'Atlantic Beach', 'NY', '11509'),
#  (1154901, 'Monique', 'Massey', '1819 West 15th Street', 'Attica', 'NY', '14011'),
#  (1078076, 'Arthur', 'Barajas', '16106 North 24th Street', 'Au Sable Forks', 'NY', '12912'),
#  (1062981, 'Lois', 'Lyons', '16106 North 24th Street', 'Au Sable Forks', 'NY', '12912'),
#  (1074688, 'Timothy', 'Vest', '12 Ontario Road', 'Au Sable Forks', 'NY', '12912'),
#  (1073903, 'Sonya', 'Camacho', '1890 North 12th Street', 'Auburn', 'NY', '13022'),
#  (1089604, 'Justin', 'Carrington', '20281 West 11th Street', 'Auburn', 'NY', '13024'),
#  (1118391, 'Brock', 'Huffman', '2153 North 17th Street', 'Auburn', 'NY', '13024'),
#  (1061624, 'Benjamin', 'Knighton', '168 West Garvey Street', 'Auburn', 'NY', '13022'),
#  (1189082, 'Susan', 'Newell', '2153 North 17th Street', 'Auburn', 'NY', '13024'),
#  (1073661, 'Seth', 'Parker', '1748 Marks Avenue', 'Auburn', 'NY', '13022'),
#  (1161066, 'Sarah', 'Phan', '20281 West 11th Street', 'Auburn', 'NY', '13024'),
#  (1061733, 'Joseph', 'Quintana', '168 West Garvey Street', 'Auburn', 'NY', '13022'),
#  (1019224, 'Todd', 'Rathbone', '20281 West 11th Street', 'Auburn', 'NY', '13024'),
#  (1193163, 'Martha', 'Rhodes', '1008 Gaston Road', 'Auburn', 'NY', '13024'),
#  (1049545, 'Donald', 'Vazquez', '1748 Marks Avenue', 'Auburn', 'NY', '13022'),
#  (1109093, 'Beverly', 'Lucas', '17000 West 13th Street', 'Auriesville', 'NY', '12016'),
#  (1049247, 'Antonio', 'Mcgowan', '13114 East 14th Street', 'Auriesville', 'NY', '12016'),
#  (1033840, 'Michelle', 'Vazquez', '2191 West 3rd Street', 'Auriesville', 'NY', '12016'),
#  (1106571, 'Louise', 'Crum', '16565 North 7th Street', 'Aurora', 'NY', '13026'),
#  (1139801, 'Tom', 'Denton', '1009 North 11th Street', 'Averill Park', 'NY', '12018'),
#  (1067051, 'William', 'Hoffmann', '1009 North 11th Street', 'Averill Park', 'NY', '12018'),
#  (1171806, 'Harold', 'Welch', '1891 West 7th Street', 'Averill Park', 'NY', '12018'),
#  (1145176, 'Micah', 'Zavala', '1891 West 7th Street', 'Averill Park', 'NY', '12018'),
#  (1019137, 'Juanita', 'Jennings', '14903 West 25th Street', 'Avon', 'NY', '14414'),
#  (1179174, 'Donna', 'Hill', '1099 Quinn Avenue', 'Babylon', 'NY', '11702'),
#  (1005854, 'Christine', 'Arrington', '1565 Lincoln Drive', 'Bakers Mills', 'NY', '12811'),
#  (1110392, 'Donna', 'Madden', '1642 24th Street', 'Bakers Mills', 'NY', '12811'),
#  (1096451, 'Sandra', 'Montano', '1642 24th Street', 'Bakers Mills', 'NY', '12811'),
#  (1034249, 'Jana', 'Nance', '1565 Lincoln Drive', 'Bakers Mills', 'NY', '12811'),
#  (1007611, 'Dorothy', 'Copley', '1676 North 13th Street', 'Baldwin Place', 'NY', '10505'),
#  (1003465, 'Wayne', 'Falgoust', '1676 North 13th Street', 'Baldwin Place', 'NY', '10505'),
#  (1015450, 'Israel', 'Hale', '1754 West 15th Street', 'Bangall', 'NY', '12506'),
#  (1033640, 'Jefferson', 'Norman', '1754 West 15th Street', 'Bangall', 'NY', '12506'),
#  (1136534, 'Aaron', 'Mcnutt', '17981 North 12th Street', 'Barton', 'NY', '13734'),
#  (1157700, 'Tiffany', 'Nickerson', '17981 North 12th Street', 'Barton', 'NY', '13734'),
#  (1161648, 'Tammy', 'Chamblee', '1749 East 17th Street', 'Basom', 'NY', '14013'),
#  (1195624, 'Ty', 'Dale', '1716 North 11th Street', 'Batavia', 'NY', '14021'),
#  (1015766, 'Andrea', 'Kiefer', '1716 North 11th Street', 'Batavia', 'NY', '14021'),
#  (1201033, 'Jonathan', 'Kirkman', '21297 North 1st Street', 'Batavia', 'NY', '14021'),
#  (1003597, 'Margaret', 'Fleming', '1201 East 15th Street', 'Bath', 'NY', '14810'),
#  (1097601, 'Stacey', 'West', '1167 Willow Road', 'Bay Shore', 'NY', '11706'),
#  (1065531, 'Mohammad', 'Sands', '130 West Charleston Road', 'Bayport', 'NY', '11705'),
#  (1148202, 'Debra', 'Arroyo', '1942 East 21st Street', 'Bayside', 'NY', '11360'),
#  (1155713, 'Jack', 'Mccorkle', '20092 North 12th Street', 'Bayside', 'NY', '11360'),
#  (1001557, 'Francine', 'Baxter', '12996 North 15th Street', 'Beaver Dams', 'NY', '14812'),
#  (1083951, 'Jon', 'Moncrief', '1405 East 3rd Street', 'Beaver Dams', 'NY', '14812'),
#  (1061062, 'Tina', 'Prewitt', '12996 North 15th Street', 'Beaver Dams', 'NY', '14812'),
#  (1176531, 'Laurence', 'Vela', '12996 North 15th Street', 'Beaver Dams', 'NY', '14812'),
#  (1102201, 'Vern', 'Conrad', '1580 North 13th Street', 'Bedford', 'NY', '10506'),
#  (1002006, 'Ricky', 'Schell', '128 North Greene Street', 'Bedford Hills', 'NY', '10507'),
#  (1053681, 'Ashley', 'Chen', '1000 East Cross Highway', 'Bemus Point', 'NY', '14712'),
#  (1063881, 'Santiago', 'Christensen', '1000 East Cross Highway', 'Bemus Point', 'NY', '14712'),
#  (1012870, 'Debra', 'Kelso', '1000 East Cross Highway', 'Bemus Point', 'NY', '14712'),
#  (1188298, 'Judith', 'Pappas', '1113 Delaney Parkway', 'Berkshire', 'NY', '13736'),
#  (1093435, 'Donald', 'Rios', '1113 Delaney Parkway', 'Berkshire', 'NY', '13736'),
#  (1124367, 'Bryant', 'Counts', '2227 West 10th Street', 'Berlin', 'NY', '12022'),
#  (1042493, 'Leah', 'Marx', '2227 West 10th Street', 'Berlin', 'NY', '12022'),
#  (1145553, 'Brian', 'Romano', '13795 West 14th Street', 'Berne', 'NY', '12023'),
#  (1026433, 'Margaret', 'Serrano', '1904 Ford Road', 'Bernhards Bay', 'NY', '13028'),
#  (1185990, 'Etta', 'Hanson', '1101 4th Street', 'Bethpage', 'NY', '11714'),
#  (1025197, 'Alejandro', 'Petersen', '1547 West Poplar Road', 'Big Flats', 'NY', '14814'),
#  (1063149, 'Wanda', 'Yang', '1644 West 6th Street', 'Big Flats', 'NY', '14814'),
#  (1091361, 'Robbie', 'Crowley', '15197 East 15th Street', 'Binghamton', 'NY', '13904'),
#  (1167026, 'Julie', 'John', '1460 Madison Highway', 'Binghamton', 'NY', '13901'),
#  (1005185, 'Michael', 'Blankenship', '1140 McCausland Street', 'Black River', 'NY', '13612'),
#  (1072022, 'Arturo', 'Garrity', '1140 McCausland Street', 'Black River', 'NY', '13612'),
#  (1067856, 'Marian', 'Mcelroy', '1140 McCausland Street', 'Black River', 'NY', '13612'),
#  (1017497, 'Betty', 'Applewhite', '1525 East Hornbeam Road', 'Blauvelt', 'NY', '10913'),
#  (1002426, 'Thomas', 'Blount', '1589 Jefferson Street', 'Bloomingburg', 'NY', '12721'),
#  (1068440, 'Linda', 'Good', '1031 North Washington Boulevard', 'Bloomingburg', 'NY', '12721'),
#  (1171048, 'Geraldine', 'Weeks', '1031 North Washington Boulevard', 'Bloomingburg', 'NY', '12721'),
#  (1069921, 'Julie', 'Broome', '13039 East 6th Street', 'Bloomingdale', 'NY', '12913'),
#  (1180408, 'Charlotte', 'Lent', '13039 East 6th Street', 'Bloomingdale', 'NY', '12913'),
#  (1169824, 'Allison', 'Vazquez', '13039 East 6th Street', 'Bloomingdale', 'NY', '12913'),
#  (1111609, 'Alfred', 'Pitts', '1784 East Clayton Parkway', 'Blossvale', 'NY', '13308'),
#  (1170000, 'Alonzo', 'Blue', '1127 West 5th Street', 'Blue Mountain Lake', 'NY', '12812'),
#  (1078772, 'Julio', 'Mader', '14018 East 11th Street', 'Blue Mountain Lake', 'NY', '12812'),
#  (1035658, 'Barbara', 'Valentine', '1127 West 5th Street', 'Blue Mountain Lake', 'NY', '12812'),
#  (1090411, 'Jeannette', 'Sherrod', '1182 West 15th Street', 'Blue Point', 'NY', '11715'),
#  (1035061, 'Judith', 'Haight', '1787 Basin Road', 'Bohemia', 'NY', '11716'),
#  (1092198, 'Riley', 'Hale', '20556 East 5th Street', 'Bohemia', 'NY', '11716'),
#  (1137503, 'Maria', 'Boggess', '2149 Edwards Boulevard', 'Bolton Landing', 'NY', '12814'),
#  (1116112, 'Richard', 'Reynolds', '2149 Edwards Boulevard', 'Bolton Landing', 'NY', '12814'),
#  (1057873, 'Kimberly', 'Vang', '1757 25th Street', 'Bovina Center', 'NY', '13740'),
#  (1166277, 'Joan', 'Cardwell', '13673 East 10th Street', 'Bradford', 'NY', '14815'),
#  (1193434, 'Dorian', 'Chavez', '13673 East 10th Street', 'Bradford', 'NY', '14815'),
#  (1065048, 'Juanita', 'Jack', '13673 East 10th Street', 'Bradford', 'NY', '14815'),
#  (1112728, 'Joseph', 'Grove', '1360 West Hanley Road', 'Branchport', 'NY', '14418'),
#  (1040995, 'Evelyn', 'Mckinney', '1360 West Hanley Road', 'Branchport', 'NY', '14418'),
#  (1062669, 'Christy', 'Alston', '1714 James Road', 'Brantingham', 'NY', '13312'),
#  (1160925, 'Marvin', 'Dickson', '1714 James Road', 'Brantingham', 'NY', '13312'),
#  (1090873, 'Mark', 'Edmondson', '1714 James Road', 'Brantingham', 'NY', '13312'),
#  (1199374, 'Arnold', 'Mcreynolds', '1265 East 4th Street', 'Brentwood', 'NY', '11717'),
#  (1135331, 'Nancy', 'Jacobs', '1775 Burton Street', 'Brewerton', 'NY', '13029'),
#  (1038661, 'Sherri', 'Borrego', '1953 North 24th Street', 'Brier Hill', 'NY', '13614'),
#  (1032644, 'Lenora', 'Cline', '16626 West 17th Street', 'Brier Hill', 'NY', '13614'),
#  (1050381, 'Sam', 'Fries', '16626 West 17th Street', 'Brier Hill', 'NY', '13614'),
#  (1023460, 'Charles', 'Isom', '1953 North 24th Street', 'Brier Hill', 'NY', '13614'),
#  (1162539, 'Joseph', 'Worthington', '1157 7th Street', 'Brightwaters', 'NY', '11718'),
#  (1179971, 'David', 'Day', '15 West Bristlecone Avenue', 'Brockport', 'NY', '14420'),
#  (1078879, 'Jacqueline', 'Lincoln', '15 West Bristlecone Avenue', 'Brockport', 'NY', '14420'),
#  (1200280, 'Jarrod', 'Broome', '1324 East 15th Street', 'Brocton', 'NY', '14716'),
#  (1020348, 'James', 'Knott', '1502 Buckingham Road', 'Brocton', 'NY', '14716'),
#  (1088043, 'Jeremy', 'Larue', '13356 East 11th Street', 'Brocton', 'NY', '14716'),
#  (1119911, 'Dustin', 'Coles', '1992 East Burton Street', 'Bronx', 'NY', '10451'),
#  (1023804, 'Annie', 'Conklin', '1874 16th Street', 'Bronx', 'NY', '10470'),
#  (1165039, 'Maria', 'Cornish', '1781 West 14th Street', 'Bronx', 'NY', '10473'),
#  (1020404, 'Elizabeth', 'Dube', '1683 East 7th Street', 'Bronx', 'NY', '10458'),
#  (1186242, 'Robert', 'Flynn', '1940 North Richview Road', 'Bronx', 'NY', '10473'),
#  (1195425, 'Jack', 'Guerrero', '1127 Madison Boulevard', 'Bronx', 'NY', '10460'),
#  (1070873, 'Lisa', 'Hanks', '12741 West 21st Street', 'Bronx', 'NY', '10458'),
#  (1120168, 'Morgan', 'Herring', '1866 Cleveland Drive', 'Bronx', 'NY', '10457'),
#  (1021480, 'Son', 'Hollinger', '1683 East 7th Street', 'Bronx', 'NY', '10458'),
#  (1187436, 'Angela', 'Larson', '1874 16th Street', 'Bronx', 'NY', '10470'),
#  (1032512, 'Elizabeth', 'Major', '11330 North 16th Street', 'Bronx', 'NY', '10468'),
#  (1038217, 'Maria', 'Middleton', '1563 North 8th Street', 'Bronx', 'NY', '10467'),
#  (1188265, 'Brad', 'Moffett', '14533 North 18th Street', 'Bronx', 'NY', '10453'),
#  (1039008, 'Aldo', 'Navarro', '20165 East 1st Street', 'Bronx', 'NY', '10459'),
#  (1028676, 'Virginia', "O'Connor", '12741 West 21st Street', 'Bronx', 'NY', '10458'),
#  (1068588, 'Leonard', 'Pfaff', '184 North 24th Street', 'Bronx', 'NY', '10466'),
#  (1143117, 'Tracy', 'Powers', '20165 East 1st Street', 'Bronx', 'NY', '10459'),
#  (1198077, 'Sharon', 'Redd', '1866 Cleveland Drive', 'Bronx', 'NY', '10457'),
#  (1067957, 'Jeremy', 'Redden', '1952 East 3rd Street', 'Bronx', 'NY', '10457'),
#  (1181742, 'Ruth', 'Saunders', '1992 East Burton Street', 'Bronx', 'NY', '10451'),
#  (1182813, 'John', 'Toole', '20165 East 1st Street', 'Bronx', 'NY', '10459'),
#  (1157405, 'Bill', 'Trotter', '1992 East Burton Street', 'Bronx', 'NY', '10451'),
#  (1065386, 'Stephanie', 'Velasquez', '14533 North 18th Street', 'Bronx', 'NY', '10453'),
#  (1186709, 'Clinton', 'Whitfield', '1683 East 7th Street', 'Bronx', 'NY', '10458'),
#  (1116289, 'Willie', 'Zapata', '1781 West 14th Street', 'Bronx', 'NY', '10473'),
#  (1157216, 'Barbara', 'Sanders', '1031 West 25th Street', 'Brookfield', 'NY', '13314'),
#  (1114463, 'Maxwell', 'Hancock', '2111 West 4th Street', 'Brookhaven', 'NY', '11719'),
#  (1031342, 'Anthony', 'Lawson', '2111 West 4th Street', 'Brookhaven', 'NY', '11719'),
#  (1136270, 'Alfonso', 'West', '2111 West 4th Street', 'Brookhaven', 'NY', '11719'),
#  (1142631, 'Kathy', 'Berg', '17734 East 10th Street', 'Brooklyn', 'NY', '11215'),
#  (1099504, 'Frank', 'Blackwell', '200 Lowell Avenue', 'Brooklyn', 'NY', '11247'),
#  (1162130, 'Leonardo', 'Byrd', '1591 North Airport Road', 'Brooklyn', 'NY', '11224'),
#  (1135944, 'Dorothy', 'Davis', '1121 North Campus Boulevard', 'Brooklyn', 'NY', '11254'),
#  (1155647, 'Lois', 'Dent', '1408 East 7th Street', 'Brooklyn', 'NY', '11230'),
#  (1051863, 'Richard', 'Holbrook', '1121 North Campus Boulevard', 'Brooklyn', 'NY', '11254'),
#  (1061622, 'Christina', 'Holliday', '114 North 2nd Street', 'Brooklyn', 'NY', '11218'),
#  (1124503, 'Adam', 'Howard', '1345 23rd Street', 'Brooklyn', 'NY', '11247'),
#  (1077472, 'Jenna', 'Jessup', '2010 Holly Avenue', 'Brooklyn', 'NY', '11205'),
#  (1061098, 'Sharon', 'Mcintosh', '1170 West 24th Street', 'Brooklyn', 'NY', '11237'),
#  (1090169, 'William', 'Mckee', '1416 Sequoia Boulevard', 'Brooklyn', 'NY', '11208'),
#  (1123879, 'Thurman', 'Mckenna', '1069 Sullivan Street', 'Brooklyn', 'NY', '11205'),
#  (1100801, 'Catherine', 'Montes', '1238 East 23rd Street', 'Brooklyn', 'NY', '11247'),
#  (1014259, 'Russell', 'Peck', '1061 Windsor Road', 'Brooklyn', 'NY', '11248'),
#  (1166828, 'Antonio', 'Pedigo', '1906 Alder Avenue', 'Brooklyn', 'NY', '11217'),
#  (1166474, 'Rigoberto', 'Polanco', '13324 East 6th Street', 'Brooklyn', 'NY', '11210'),
#  (1049338, 'Dante', 'Russ', '1061 Windsor Road', 'Brooklyn', 'NY', '11248'),
#  (1177984, 'Loretta', 'Smallwood', '13324 East 6th Street', 'Brooklyn', 'NY', '11210'),
#  (1091095, 'Dorothy', 'Sullivan', '200 Lowell Avenue', 'Brooklyn', 'NY', '11247'),
#  (1110389, 'Elizabeth', 'Tyler', '1906 Alder Avenue', 'Brooklyn', 'NY', '11217'),
#  (1114178, 'Edward', 'Yang', '1165 North Ladue Road', 'Brooktondale', 'NY', '14817'),
#  (1051384, 'Jane', 'Baron', '102 East Charleston Road', 'Brownville', 'NY', '13615'),
#  (1119212, 'Charlene', 'Hatchett', '102 East Charleston Road', 'Brownville', 'NY', '13615'),
#  (1072530, 'Harry', 'Rudolph', '102 East Charleston Road', 'Brownville', 'NY', '13615'),
#  (1201193, 'Louis', 'Strong', '102 East Charleston Road', 'Brownville', 'NY', '13615'),
#  (1081757, 'Marc', 'Tye', '102 East Charleston Road', 'Brownville', 'NY', '13615'),
#  (1193531, 'Carlton', 'Snyder', '1330 West Kerry Boulevard', 'Brushton', 'NY', '12916'),
#  (1035631, 'Erma', 'Armstrong', '1189 West Spruce Parkway', 'Buffalo', 'NY', '14208'),
#  (1125602, 'Howard', 'Austin', '17962 North 24th Street', 'Buffalo', 'NY', '14204'),
#  (1192412, 'Anne', 'Bloom', '1655 Portland Road', 'Buffalo', 'NY', '14273'),
#  (1008556, 'Erika', 'Bloomfield', '1365 North 7th Street', 'Buffalo', 'NY', '14264'),
#  (1182116, 'Diane', 'Case', '12838 North 4th Street', 'Buffalo', 'NY', '14217'),
#  (1049436, 'James', 'Dale', '1189 West Spruce Parkway', 'Buffalo', 'NY', '14208'),
#  (1156623, 'Aaron', 'Dubose', '1365 North 7th Street', 'Buffalo', 'NY', '14264'),
#  (1200705, 'Douglas', 'Dugan', '1318 West 21st Street', 'Buffalo', 'NY', '14212'),
#  (1112529, 'Edith', 'Engler', '108 West Holly Road', 'Buffalo', 'NY', '14213'),
#  (1185178, 'Paula', 'Fowler', '21665 East 17th Street', 'Buffalo', 'NY', '14217'),
#  (1041394, 'Phyllis', 'Garrick', '1551 West 8th Street', 'Buffalo', 'NY', '14261'),
#  (1177717, 'Marie', 'Giese', '1574 Union Drive', 'Buffalo', 'NY', '14207'),
#  (1168641, 'Freda', 'Hendrix', '10572 East 6th Street', 'Buffalo', 'NY', '14261'),
#  (1127525, 'Rachel', 'Holston', '1986 McCausland Street', 'Buffalo', 'NY', '14228'),
#  (1097949, 'Marion', 'Johnston', '1272 19th Street', 'Buffalo', 'NY', '14261'),
#  (1084824, 'Victor', 'Kirsch', '1378 East 24th Street', 'Buffalo', 'NY', '14225'),
#  (1163787, 'Abe', 'Lance', '1655 Portland Road', 'Buffalo', 'NY', '14273'),
#  (1042924, 'Ryan', 'Lemieux', '15116 East 22nd Street', 'Buffalo', 'NY', '14260'),
#  (1016690, 'Eric', 'Lovell', '1986 McCausland Street', 'Buffalo', 'NY', '14228'),
#  (1170294, 'Elijah', 'Lovett', '11402 North 4th Street', 'Buffalo', 'NY', '14210'),
#  (1073926, 'Douglas', 'Lucky', '1328 Medlar Road', 'Buffalo', 'NY', '14226'),
#  (1166611, 'John', 'Martinez', '16991 North 22nd Street', 'Buffalo', 'NY', '14207'),
#  (1171135, 'Bethany', 'Mcrae', '1700 East 12th Street', 'Buffalo', 'NY', '14226'),
#  (1164191, 'Samuel', 'Moseley', '1986 McCausland Street', 'Buffalo', 'NY', '14228'),
#  (1173361, 'Katherine', "O'Daniel", '1365 North 7th Street', 'Buffalo', 'NY', '14264'),
#  (1046222, 'Margaret', 'Osborne', '1700 East 12th Street', 'Buffalo', 'NY', '14226'),
#  (1017893, 'Angel', 'Parke', '1552 West Larch Avenue', 'Buffalo', 'NY', '14216'),
#  (1163961, 'David', 'Pinson', '1378 East 24th Street', 'Buffalo', 'NY', '14225'),
#  (1150915, 'Thomas', 'Potter', '1328 Medlar Road', 'Buffalo', 'NY', '14226'),
#  (1127186, 'Joseph', 'Robbins', '189 East 5th Street', 'Buffalo', 'NY', '14223'),
#  (1170178, 'Pam', 'Sheppard', '1578 West 2nd Street', 'Buffalo', 'NY', '14224'),
#  (1141949, 'Betsy', 'Speed', '1986 McCausland Street', 'Buffalo', 'NY', '14228'),
#  (1160652, 'Justin', 'Tolbert', '1386 West Benton Road', 'Buffalo', 'NY', '14280'),
#  (1164314, 'Gary', 'Turnbull', '1552 West Larch Avenue', 'Buffalo', 'NY', '14216'),
#  (1088805, 'Henry', 'Vu', '1189 West Spruce Parkway', 'Buffalo', 'NY', '14208'),
#  (1033509, 'Seth', 'Williamson', '11402 North 4th Street', 'Buffalo', 'NY', '14210'),
#  (1163921, 'Maria', 'Wu', '1604 East Warder Road', 'Buffalo', 'NY', '14264'),
#  (1201155, 'William', 'Prather', '1856 East 16th Street', 'Bullville', 'NY', '10915'),
#  (1061129, 'Cheryl', 'Conway', '1519 North 1st Street', 'Burke', 'NY', '12917'),
#  (1084453, 'Robbie', 'Dalrymple', '192 West 21st Street', 'Burt', 'NY', '14028'),
#  (1009501, 'Dorothy', 'Mack', '192 West 21st Street', 'Burt', 'NY', '14028'),
#  (1093910, 'Elias', 'Lock', '1275 West Euclid Road', 'Buskirk', 'NY', '12028'),
#  (1040248, 'Frances', 'Yee', '1275 West Euclid Road', 'Buskirk', 'NY', '12028'),
#  (1078378, 'Christopher', 'Boyle', '1320 East Poplar Street', 'Callicoon', 'NY', '12723'),
#  (1098837, 'Esperanza', 'Gentile', '1320 East Poplar Street', 'Callicoon', 'NY', '12723'),
#  (1136517, 'Mildred', 'Lowman', '1770 North Meade Street', 'Callicoon', 'NY', '12723'),
#  (1038977, 'Linda', 'Marino', '1770 North Meade Street', 'Callicoon', 'NY', '12723'),
#  (1024098, 'Ulysses', 'Mcclure', '12588 West 18th Street', 'Callicoon', 'NY', '12723'),
#  (1142251, 'Kelvin', 'Alejandro', '11905 West 11th Street', 'Calverton', 'NY', '11933'),
#  (1193073, 'Ursula', 'Skaggs', '1221 East 5th Street', 'Calverton', 'NY', '11933'),
#  (1170502, 'Troy', 'Torres', '1221 East 5th Street', 'Calverton', 'NY', '11933'),
#  (1015206, 'Matt', 'Gauthier', '1920 East Silver Street', 'Camden', 'NY', '13316'),
#  (1160474, 'Hiram', 'Lewis', '1568 North 14th Street', 'Camden', 'NY', '13316'),
#  (1082305, 'Javier', 'Lilly', '1568 North 14th Street', 'Camden', 'NY', '13316'),
#  (1020891, 'Robert', 'Lauer', '1539 West 19th Street', 'Cameron', 'NY', '14819'),
#  (1020036, 'Cliff', 'Beach', '1987 West 10th Street', 'Campbell Hall', 'NY', '10916'),
#  (1173955, 'Katie', 'Bolden', '1260 Baxter Street', 'Campbell Hall', 'NY', '10916'),
#  (1026530, 'Mary', 'George', '1260 Baxter Street', 'Campbell Hall', 'NY', '10916'),
#  (1199846, 'Rodolfo', 'Malcolm', '1987 West 10th Street', 'Campbell Hall', 'NY', '10916'),
#  (1069373, 'Lois', 'Maxwell', '2009 East Hoover Highway', 'Canastota', 'NY', '13032'),
#  (1174186, 'Clarice', 'Thornhill', '2009 East Hoover Highway', 'Canastota', 'NY', '13032'),
#  (1006649, 'Tanya', 'Leggett', '209 West 14th Street', 'Cape Vincent', 'NY', '13618'),
#  (1045818, 'Billie', 'Hammond', '1829 West Grant Boulevard', 'Carlisle', 'NY', '12031'),
#  (1152213, 'Janine', 'Nash', '1128 North Arthur Street', 'Carlisle', 'NY', '12031'),
#  (1081534, 'Sandy', 'Lair', '11973 East 2nd Street', 'Carmel', 'NY', '10512'),
#  (1152254, 'Justin', 'Lang', '1258 Neely Road', 'Carmel', 'NY', '10512'),
#  (1123398, 'Michael', 'Serrano', '21374 West 2nd Street', 'Cassadaga', 'NY', '14718'),
#  (1114444, 'Shane', 'Schroeder', '19333 West 15th Street', 'Castle Point', 'NY', '12511'),
#  (1157706, 'Gary', 'Mcmichael', '1283 Cypress Road', 'Castleton On Hudson', 'NY', '12033'),
#  (1008591, 'Calvin', 'Burr', '15494 East 4th Street', 'Castorland', 'NY', '13620'),
#  (1199405, 'Fritz', 'Barry', '14589 East 13th Street', 'Cattaraugus', 'NY', '14719'),
#  (1032596, 'Sofia', 'Gruber', '1266 Van Buren Boulevard', 'Cayuga', 'NY', '13034'),
#  (1139252, 'Erica', 'Guerra', '1239 North Walker Street', 'Cazenovia', 'NY', '13035'),
#  (1047176, 'Frances', 'Leal', '1239 North Walker Street', 'Cazenovia', 'NY', '13035'),
#  (1077063, 'Norris', 'Anderson', '1573 Stewart Road', 'Cedarhurst', 'NY', '11516'),
#  (1027968, 'Michael', 'Abernathy', '1556 Madison Boulevard', 'Center Moriches', 'NY', '11934'),
#  (1035009, 'Robert', 'Dunton', '1227 West 15th Street', 'Centereach', 'NY', '11720'),
#  (1114880, 'Louise', 'Berger', '201 West Harrison Street', 'Central Square', 'NY', '13036'),
#  (1023184, 'Connie', 'Girard', '2044 West White Road', 'Central Square', 'NY', '13036'),
#  (1149182, 'Anna', 'Woodward', '2044 West White Road', 'Central Square', 'NY', '13036'),
#  (1122554, 'Marvin', 'Duck', '135 West 15th Street', 'Chadwicks', 'NY', '13319'),
#  (1145686, 'Pamela', 'Nguyen', '135 West 15th Street', 'Chadwicks', 'NY', '13319'),
#  (1004031, 'Ali', 'Dunston', '2063 Apple Drive', 'Chelsea', 'NY', '12512'),
#  (1184671, 'Robert', 'Keener', '1380 East Watson Avenue', 'Chemung', 'NY', '14825'),
#  (1183353, 'Julia', 'Houghton', '1351 Simmons Street', 'Chenango Bridge', 'NY', '13745'),
#  (1076807, 'Lois', 'Abrego', '2077 East 25th Street', 'Cherry Creek', 'NY', '14723'),
#  (1122761, 'Nicole', 'Barron', '2077 East 25th Street', 'Cherry Creek', 'NY', '14723'),
#  (1132785, 'Sammie', 'Kiser', '2077 East 25th Street', 'Cherry Creek', 'NY', '14723'),
#  (1043181, 'Isaiah', 'Ngo', '2077 East 25th Street', 'Cherry Creek', 'NY', '14723'),
#  (1119738, 'Alfonso', 'Leblanc', '2009 North 24th Street', 'Cherry Plain', 'NY', '12040'),
#  (1151412, 'Casey', 'Wilkerson', '2009 North 24th Street', 'Cherry Plain', 'NY', '12040'),
#  (1161784, 'Jessica', 'Ham', '1143 22nd Street', 'Chester', 'NY', '10918'),
#  (1144261, 'Janine', 'Kline', '166 Basin Road', 'Chester', 'NY', '10918'),
#  (1082368, 'Martha', 'Mccartney', '166 Basin Road', 'Chester', 'NY', '10918'),
#  (1138577, 'Mickey', 'Mosley', '1143 22nd Street', 'Chester', 'NY', '10918'),
#  (1157559, 'Anthony', 'Abney', '2067 West 15th Street', 'Chichester', 'NY', '12416'),
#  (1107042, 'Darren', 'Cazares', '1262 North Yew Place', 'Chippewa Bay', 'NY', '13623'),
#  (1167415, 'Vance', 'Reynolds', '18 East Charleston Road', 'Chittenango', 'NY', '13037'),
#  (1117065, 'Bill', 'Murillo', '1934 Union Highway', 'Churchville', 'NY', '14428'),
#  (1038867, 'Blaine', 'Sherwood', '1934 Union Highway', 'Churchville', 'NY', '14428'),
#  (1005352, 'Martin', 'Andersen', '1635 Shaw Highway', 'Cicero', 'NY', '13039'),
#  (1191425, 'Roger', 'Bouchard', '1635 Shaw Highway', 'Cicero', 'NY', '13039'),
#  (1135082, 'Kevin', 'Harris', '1635 Shaw Highway', 'Cicero', 'NY', '13039'),
#  (1075254, 'Ralph', 'Bittner', '224 East 6th Street', 'Cincinnatus', 'NY', '13040'),
#  (1074686, 'Lloyd', 'Frances', '1321 North Hunter Avenue', 'Clarence', 'NY', '14031'),
#  (1008953, 'Margaret', 'Meza', '1458 Claypool Road', 'Clarkson', 'NY', '14430'),
#  (1123037, 'Marilyn', 'Pena', '1458 Claypool Road', 'Clarkson', 'NY', '14430'),
#  (1089825, 'Glen', 'Steinberg', '1156 North Baxter Avenue', 'Clarksville', 'NY', '12041'),
#  (1058274, 'Jimmy', 'Dewey', '1085 West Audobon Street', 'Claverack', 'NY', '12513'),
#  (1135058, 'Steve', 'Wilkerson', '20130 North 12th Street', 'Clay', 'NY', '13041'),
#  (1072547, 'Cedric', 'Ewing', '17042 North 20th Street', 'Clemons', 'NY', '12819'),
#  (1099225, 'Phyllis', 'Hart', '17042 North 20th Street', 'Clemons', 'NY', '12819'),
#  (1012279, 'Jennifer', 'Lindsay', '17042 North 20th Street', 'Clemons', 'NY', '12819'),
#  (1195006, 'Shawn', 'Parker', '17042 North 20th Street', 'Clemons', 'NY', '12819'),
#  (1083008, 'Deborah', 'Peterson', '1786 Oakland Road', 'Clifton Springs', 'NY', '14432'),
#  (1050190, 'Phillip', 'Redmond', '1786 Oakland Road', 'Clifton Springs', 'NY', '14432'),
#  (1176028, 'Franklin', 'Gay', '15 North 2nd Street', 'Climax', 'NY', '12042'),
#  (1087535, 'Patty', 'Singleton', '15 North 2nd Street', 'Climax', 'NY', '12042'),
#  (1010848, 'Rocky', 'Herrin', '1971 Cross Boulevard', 'Clinton', 'NY', '13323'),
#  (1019854, 'Junior', 'Yee', '1971 Cross Boulevard', 'Clinton', 'NY', '13323'),
#  (1074247, 'David', 'Jackson', '1122 Bell Street', 'Clinton Corners', 'NY', '12514'),
#  (1173203, 'Gerald', 'Willis', '1639 East 24th Street', 'Clinton Corners', 'NY', '12514'),
#  (1137389, 'Claire', 'Vinson', '1704 North 1st Street', 'Clymer', 'NY', '14724'),
#  (1163375, 'James', 'Colucci', '170 East Ridgeline Boulevard', 'Cochecton Center', 'NY', '12727'),
#  (1048278, 'Louis', 'Yeager', '170 East Ridgeline Boulevard', 'Cochecton Center', 'NY', '12727'),
#  (1132847, 'Jack', 'Hardman', '18994 West 12th Street', 'Coeymans', 'NY', '12045'),
#  (1079217, 'Ellis', 'Higgins', '1003 Anderson Road', 'Coeymans', 'NY', '12045'),
#  (1069820, 'Beatriz', 'Mckinley', '134 Price Avenue', 'Cohocton', 'NY', '14826'),
#  (1036100, 'Rocky', 'Saunders', '1102 Pine Road', 'Colden', 'NY', '14033'),
#  (1027759, 'Jorge', 'Dorsey', '17978 East 4th Street', 'College Point', 'NY', '11356'),
#  (1155207, 'Allan', 'Phillips', '10420 West 5th Street', 'Collins', 'NY', '14034'),
#  (1166511, 'Pamela', 'Newcomb', '2215 North 25th Street', 'Collins Center', 'NY', '14035'),
#  (1002988, 'Thomas', 'Altman', '1388 West 6th Street', 'Colton', 'NY', '13625'),
#  (1018356, 'Marlene', 'Bogle', '1388 West 6th Street', 'Colton', 'NY', '13625'),
#  (1157397, 'Elaine', 'Coffey', '1388 West 6th Street', 'Colton', 'NY', '13625'),
#  (1143469, 'Joshua', 'Pacheco', '1247 Hill Avenue', 'Columbiaville', 'NY', '12050'),
#  (1038904, 'Stephen', 'Runyon', '1279 Willamette Avenue', 'Columbiaville', 'NY', '12050'),
#  (1134656, 'Van', 'Swenson', '1247 Hill Avenue', 'Columbiaville', 'NY', '12050'),
#  (1100080, 'Antonio', 'Milton', '2009 North 14th Street', 'Commack', 'NY', '11725'),
#  (1111187, 'Sarah', 'Petty', '2009 North 14th Street', 'Commack', 'NY', '11725'),
#  (1099245, 'Kristen', 'Friel', '16769 14th Street', 'Congers', 'NY', '10920'),
#  (1141380, 'Barbara', 'Humphrey', '11072 North 20th Street', 'Congers', 'NY', '10920'),
#  (1131277, 'William', 'Ramirez', '11072 North 20th Street', 'Congers', 'NY', '10920'),
#  (1122069, 'Royce', 'Wescott', '11072 North 20th Street', 'Congers', 'NY', '10920'),
#  (1086251, 'Delores', 'Brower', '17829 West 5th Street', 'Conklin', 'NY', '13748'),
#  (1068702, 'Patricia', 'Mitchell', '17829 West 5th Street', 'Conklin', 'NY', '13748'),
#  (1106170, 'Maria', 'Summerville', '17829 West 5th Street', 'Conklin', 'NY', '13748'),
#  (1017462, 'Louis', 'Cosby', '1607 North Kerry Road', 'Copake', 'NY', '12516'),
#  (1002586, 'Lamar', 'Pettway', '16308 West 17th Street', 'Copake', 'NY', '12516'),
#  (1169275, 'Paula', 'Everett', '2107 West 21st Street', 'Coram', 'NY', '11727'),
#  (1119215, 'Robert', 'Cote', '15128 North 17th Street', 'Corning', 'NY', '14831'),
#  (1118330, 'Lori', 'Burris', '191 West Hoover Boulevard', 'Cornwall', 'NY', '12518'),
#  (1052440, 'Jennifer', 'Griggs', '1621 West Maplewood Road', 'Cortland', 'NY', '13045'),
#  (1099132, 'Linda', 'Cahill', '12582 West 1st Street', 'Cortlandt Manor', 'NY', '10567'),
#  (1172236, 'Rolando', 'Campbell', '20558 North 21st Street', 'Cortlandt Manor', 'NY', '10567'),
#  (1048383, 'Donna', 'Lay', '1321 East 25th Street', 'Cragsmoor', 'NY', '12420'),
#  (1167589, 'Jeffrey', 'Barber', '1368 North Market Avenue', 'Cranberry Lake', 'NY', '12927'),
#  (1080357, 'Bill', 'Wilson', '10995 East 19th Street', 'Cranberry Lake', 'NY', '12927'),
#  (1059308, 'Molly', 'Bartel', '1831 East Johnson Avenue', 'Cuba', 'NY', '14727'),
#  (1114334, 'Patricia', 'Rosenthal', '1831 East Johnson Avenue', 'Cuba', 'NY', '14727'),
#  (1058520, 'Michael', 'Buchanan', '1525 Parkridge Road', 'Cuddebackville', 'NY', '12729'),
#  (1091629, 'Bernie', 'Justice', '1381 Barkley Street', 'Cuddebackville', 'NY', '12729'),
#  (1201032, 'Raymond', 'Lakey', '2114 North 8th Street', 'Cuddebackville', 'NY', '12729'),
#  (1106275, 'Sylvia', 'Quesada', '2114 North 8th Street', 'Cuddebackville', 'NY', '12729'),
#  (1166305, 'Myra', 'Seymour', '2114 North 8th Street', 'Cuddebackville', 'NY', '12729'),
#  (1014769, 'Bernardo', 'Sorrells', '2114 North 8th Street', 'Cuddebackville', 'NY', '12729'),
#  (1024112, 'Junior', 'Thigpen', '1381 Barkley Street', 'Cuddebackville', 'NY', '12729'),
#  (1112409, 'Alan', 'Lawson', '1291 West Wells Road', 'Davenport', 'NY', '13750'),
#  (1131853, 'Bruce', 'Montoya', '1291 West Wells Road', 'Davenport', 'NY', '13750'),
#  (1089088, 'Kerry', 'Stiles', '1730 North Bristlecone Road', 'Davenport Center', 'NY', '13751'),
#  (1146613, 'Christine', 'Shackelford', '167 Wellington Place', 'De Peyster', 'NY', '13633'),
#  (1124976, 'Cynthia', 'Spriggs', '167 Wellington Place', 'De Peyster', 'NY', '13633'),
#  (1067222, 'Richard', 'Clements', '2181 West 24th Street', 'Deansboro', 'NY', '13328'),
#  (1086211, 'Elizabeth', 'Kramer', '2181 West 24th Street', 'Deansboro', 'NY', '13328'),
#  (1096295, 'Susan', 'Green', '12796 West 12th Street', 'Denmark', 'NY', '13631'),
#  (1022577, 'Lance', 'Spann', '13900 North 10th Street', 'Denmark', 'NY', '13631'),
#  (1053946, 'Tracey', 'Kimbrough', '1712 West 8th Street', 'Derby', 'NY', '14047'),
#  (1095276, 'Katherine', 'Mckibben', '1712 West 8th Street', 'Derby', 'NY', '14047'),
#  (1117111, 'Blake', 'Morrow', '1712 West 8th Street', 'Derby', 'NY', '14047'),
#  (1050840, 'Dorothy', 'Jackson', '1409 West Madison Road', 'Dickinson Center', 'NY', '12930'),
#  (1149858, 'Lois', 'Camacho', '1890 North 2nd Street', 'Dobbs Ferry', 'NY', '10522'),
#  (1004274, 'Rachel', 'Hernandez', '1890 North 2nd Street', 'Dobbs Ferry', 'NY', '10522'),
#  (1149265, 'Christine', 'Mccurdy', '1890 North 2nd Street', 'Dobbs Ferry', 'NY', '10522'),
#  (1139370, 'Peter', 'Sherwood', '1890 North 2nd Street', 'Dobbs Ferry', 'NY', '10522'),
#  (1073333, 'Lillie', 'Wolff', '1264 North 8th Street', 'Dobbs Ferry', 'NY', '10522'),
#  (1181233, 'Ted', 'Criswell', '1728 North Shaw Boulevard', 'Dormansville', 'NY', '12055'),
#  (1171313, 'Owen', 'Frey', '1728 North Shaw Boulevard', 'Dormansville', 'NY', '12055'),
#  (1154103, 'Robert', 'Moore', '1728 North Shaw Boulevard', 'Dormansville', 'NY', '12055'),
#  (1097805, 'Jesse', 'Slaton', '1728 North Shaw Boulevard', 'Dormansville', 'NY', '12055'),
#  (1112721, 'Edward', 'Tolman', '22120 North 17th Street', 'Dresden', 'NY', '14441'),
#  (1136774, 'Junior', 'Benton', '1981 East 3rd Street', 'Duanesburg', 'NY', '12056'),
#  (1155473, 'Daniel', 'Doran', '1697 North Gannon Road', 'Dundee', 'NY', '14837'),
#  (1131127, 'Katie', 'Lemieux', '1038 West Alder Street', 'Dunkirk', 'NY', '14048'),
#  (1156872, 'Phyllis', 'Linden', '2063 West 19th Street', 'Durham', 'NY', '12422'),
#  (1050671, 'Amber', 'Binkley', '1018 West 2nd Street', 'Eagle Bay', 'NY', '13331'),
#  (1193602, 'Calvin', 'High', '10788 West 7th Street', 'Eagle Bay', 'NY', '13331'),
#  (1043644, 'Katherine', 'Cortez', '11814 East 15th Street', 'Eagle Bridge', 'NY', '12057'),
#  (1075212, 'David', 'Munoz', '21876 East 4th Street', 'Earlville', 'NY', '13332'),
#  (1190429, 'Heather', 'Rendon', '21876 East 4th Street', 'Earlville', 'NY', '13332'),
#  (1163505, 'Ruth', 'Burnham', '1600 Hampton Road', 'East Aurora', 'NY', '14052'),
#  (1144125, 'Peter', 'Lupo', '1600 Hampton Road', 'East Aurora', 'NY', '14052'),
#  (1164075, 'Patricia', 'Walsh', '1600 Hampton Road', 'East Aurora', 'NY', '14052'),
#  (1116178, 'Katherine', 'Turnbull', '162 North Cleveland Road', 'East Concord', 'NY', '14055'),
#  (1072685, 'Maxine', 'Collier', '161 East 13th Street', 'East Elmhurst', 'NY', '11369'),
#  (1182934, 'Linda', 'Woodland', '1192 West 5th Street', 'East Elmhurst', 'NY', '11370'),
#  (1105753, 'Daniel', 'Adkins', '21419 East 18th Street', 'East Greenbush', 'NY', '12061'),
#  (1067394, 'Thomas', 'Beasley', '15751 East 8th Street', 'East Greenbush', 'NY', '12061'),
#  (1156765, 'Nicholas', 'Doran', '2012 North 5th Street', 'East Greenbush', 'NY', '12061'),
#  (1101258, 'Kathy', 'Lincoln', '15751 East 8th Street', 'East Greenbush', 'NY', '12061'),
#  (1086537, 'Kristy', 'Mathew', '2178 North 10th Street', 'East Hampton', 'NY', '11937'),
#  (1161756, 'Theresa', 'Stubbs', '2178 North 10th Street', 'East Hampton', 'NY', '11937'),
#  (1072023, 'Derek', 'Maldonado', '1510 East Wellington Street', 'East Homer', 'NY', '13056'),
#  (1154212, 'Barbara', 'Burgos', '1083 East 18th Street', 'East Jewett', 'NY', '12424'),
#  (1052430, 'Edmond', 'Hollifield', '20156 East 10th Street', 'East Moriches', 'NY', '11940'),
#  (1082357, 'Latoya', 'Patel', '17172 West 18th Street', 'East Nassau', 'NY', '12062'),
#  (1158009, 'Jeremy', 'Wetmore', '1240 Genevieve Road', 'East Northport', 'NY', '11731'),
#  (1123919, 'Drew', 'Berry', '1096 Claypool Place', 'East Quogue', 'NY', '11942'),
#  (1137943, 'Keith', 'Stokes', '1096 Claypool Place', 'East Quogue', 'NY', '11942'),
#  (1048056, 'Charles', 'Eason', '1189 West Chestnut Road', 'East Schodack', 'NY', '12063'),
#  (1132651, 'Marjorie', 'Jordan', '13727 North 7th Street', 'East Springfield', 'NY', '13333'),
#  (1054797, 'Katie', 'France', '21333 East 14th Street', 'Eden', 'NY', '14057'),
#  (1030456, 'Maurice', 'Ivey', '1341 West 8th Street', 'Edmeston', 'NY', '13335'),
#  (1078740, 'Craig', 'Palma', '1341 West 8th Street', 'Edmeston', 'NY', '13335'),
#  (1188709, 'Adriana', 'Doherty', '17015 West 22nd Street', 'Edwards', 'NY', '13635'),
#  (1085805, 'Cheryl', 'Lindsay', '17015 West 22nd Street', 'Edwards', 'NY', '13635'),
#  (1008528, 'Cleveland', 'Mccoy', '1096 West Kirkwood Road', 'Elbridge', 'NY', '13060'),
#  (1184772, 'Carlos', 'Redmond', '1096 West Kirkwood Road', 'Elbridge', 'NY', '13060'),
#  (1012175, 'Misty', 'Favela', '2201 Guinness Road', 'Eldred', 'NY', '12732'),
#  (1024145, 'Kelly', 'Gross', '12905 East 3rd Street', 'Eldred', 'NY', '12732'),
#  (1174508, 'Gerardo', 'Rosa', '12905 East 3rd Street', 'Eldred', 'NY', '12732'),
#  (1030627, 'Bernardo', 'Gonzales', '1178 Yew Street', 'Elizaville', 'NY', '12523'),
#  (1122107, 'Randy', 'Chandler', '13825 East 4th Street', 'Elka Park', 'NY', '12427'),
#  (1028094, 'Stefan', 'Lovett', '1963 Linden Street', 'Elka Park', 'NY', '12427'),
#  (1013863, 'Linda', 'Nelson', '13825 East 4th Street', 'Elka Park', 'NY', '12427'),
#  (1116727, 'Kim', 'Tobey', '13825 East 4th Street', 'Elka Park', 'NY', '12427'),
#  (1106634, 'Gregory', 'Weisman', '1963 Linden Street', 'Elka Park', 'NY', '12427'),
#  (1080722, 'June', 'Beaulieu', '18867 North 14th Street', 'Ellenburg', 'NY', '12933'),
#  (1054319, 'Jean', 'Medford', '18867 North 14th Street', 'Ellenburg', 'NY', '12933'),
#  (1191090, 'Molly', 'Knott', '1249 Wells Road', 'Ellenburg Center', 'NY', '12934'),
#  (1157109, 'Ellis', 'Vela', '1249 Wells Road', 'Ellenburg Center', 'NY', '12934'),
#  (1201052, 'Sandra', 'Johnson', '1925 West 13th Street', 'Ellenburg Depot', 'NY', '12935'),
#  (1045820, 'Ernest', 'Ketchum', '175 Chelsea Road', 'Ellenville', 'NY', '12428'),
#  (1153488, 'Leonardo', 'Corbitt', '1885 East Blue Road', 'Ellington', 'NY', '14732'),
#  (1191328, 'Gregory', 'Stein', '1885 East Blue Road', 'Ellington', 'NY', '14732'),
#  (1127249, 'Teresa', 'Tarver', '1885 East Blue Road', 'Ellington', 'NY', '14732'),
#  (1161417, 'Jack', 'Hopson', '1251 Moore Road', 'Elma', 'NY', '14059'),
#  (1079408, 'Denise', 'Lucero', '1944 East Ash Drive', 'Elma', 'NY', '14059'),
#  (1046080, 'Jonathan', 'Lance', '1659 5th Street', 'Elmira', 'NY', '14901'),
#  (1045101, 'Robyn', 'Pope', '1603 West 19th Street', 'Elmira', 'NY', '14901'),
#  (1071336, 'Ann', 'Potter', '15489 10th Street', 'Elmira', 'NY', '14904'),
#  (1069057, 'Wilmer', 'Schneider', '12065 19th Street', 'Elmira', 'NY', '14903'),
#  (1180752, 'Kenneth', 'Donner', '1562 Windsor Road', 'Endicott', 'NY', '13761'),
#  (1140108, 'Eileen', 'Gibbs', '1518 Pecan Road', 'Endicott', 'NY', '13761'),
#  (1138792, 'Cynthia', 'Hovis', '1518 Pecan Road', 'Endicott', 'NY', '13761'),
#  (1013019, 'Alice', 'Wright', '1908 North 12th Street', 'Erin', 'NY', '14838'),
#  (1075489, 'Laura', 'Carty', '1039 West 2nd Street', 'Esperance', 'NY', '12066'),
#  (1121412, 'Jeffrey', 'Cross', '16856 East 22nd Street', 'Esperance', 'NY', '12066'),
#  (1075601, 'Christina', 'King', '1039 West 2nd Street', 'Esperance', 'NY', '12066'),
#  (1124147, 'Mary', 'Garvey', '18475 West 4th Street', 'Essex', 'NY', '12936'),
#  (1084554, 'Mary', 'Brownlee', '1306 5th Street', 'Etna', 'NY', '13062'),
#  (1091998, 'Julie', 'Miller', '16716 East 14th Street', 'Etna', 'NY', '13062'),
#  (1194235, 'Elizabeth', 'Ruiz', '1263 North 16th Street', 'Fallsburg', 'NY', '12733'),
#  (1031428, 'Dino', 'Vance', '1263 North 16th Street', 'Fallsburg', 'NY', '12733'),
#  (1049672, 'Arlene', 'Darr', '156 Maryland Road', 'Far Rockaway', 'NY', '11693'),
#  (1084600, 'John', 'Hensley', '1341 East 25th Street', 'Far Rockaway', 'NY', '11695'),
#  (1130714, 'Reuben', 'Stevens', '1990 East 13th Street', 'Far Rockaway', 'NY', '11693'),
#  (1087331, 'Robert', 'Matthew', '200 North 12th Street', 'Farmersville Station', 'NY', '14060'),
#  (1054200, 'William', 'Bess', '1555 West 17th Street', 'Farmingdale', 'NY', '11736'),
#  (1080791, 'Charles', 'Brooks', '1454 Edward Road', 'Farmingdale', 'NY', '11737'),
#  (1175373, 'Tiffany', 'Gracia', '1555 West 17th Street', 'Farmingdale', 'NY', '11736'),
#  (1049980, 'Justin', 'Hardison', '1871 Broadway Place', 'Farmingdale', 'NY', '11737'),
#  (1107634, 'Rosalie', 'Townsend', '1454 Edward Road', 'Farmingdale', 'NY', '11737'),
#  (1146640, 'Lawrence', 'Andrews', '11 Newgate Road', 'Farmingville', 'NY', '11738'),
#  (1144140, 'Robin', 'Collins', '11 Newgate Road', 'Farmingville', 'NY', '11738'),
#  (1058558, 'Craig', 'Hoard', '11 Newgate Road', 'Farmingville', 'NY', '11738'),
#  (1024347, 'Antonio', 'Kelley', '1526 West 14th Street', 'Farmingville', 'NY', '11738'),
#  (1127100, 'Tina', 'Tinsley', '1526 West 14th Street', 'Farmingville', 'NY', '11738'),
#  (1026169, 'Kathy', 'Trammell', '1849 Maryland Road', 'Farmingville', 'NY', '11738'),
#  (1038501, 'Becky', 'Washburn', '1526 West 14th Street', 'Farmingville', 'NY', '11738'),
#  (1107616, 'Harry', 'Gurley', '11951 North 19th Street', 'Farnham', 'NY', '14061'),
#  (1126208, 'Evelyn', 'Schulte', '11951 North 19th Street', 'Farnham', 'NY', '14061'),
#  (1151460, 'Tasha', "O'Brien", '1752 Yew Street', 'Fine', 'NY', '13639'),
#  (1104186, 'Jane', 'Whelan', '1752 Yew Street', 'Fine', 'NY', '13639'),
#  (1158746, 'Lonnie', 'Andersen', '1790 Birch Road', 'Fishers Landing', 'NY', '13641'),
#  (1003408, 'Whitney', 'Beck', '2217 East 19th Street', 'Fishers Landing', 'NY', '13641'),
#  (1114383, 'Juan', 'Breunig', '1790 Birch Road', 'Fishers Landing', 'NY', '13641'),
#  (1171652, 'Richard', 'Crane', '1790 Birch Road', 'Fishers Landing', 'NY', '13641'),
#  (1190025, 'Theresa', 'Rice', '2217 East 19th Street', 'Fishers Landing', 'NY', '13641'),
#  (1171376, 'Kathleen', 'Augustine', '1084 North Hoover Road', 'Fishkill', 'NY', '12524'),
#  (1083206, 'Preston', 'Liles', '10723 East 14th Street', 'Fleischmanns', 'NY', '12430'),
#  (1119829, 'Zachary', 'Moseley', '10723 East 14th Street', 'Fleischmanns', 'NY', '12430'),
#  (1164152, 'Gina', 'Costello', '1544 North 15th Street', 'Floral Park', 'NY', '11002'),
#  (1027911, 'Audrey', 'Gabel', '124 West 24th Street', 'Floral Park', 'NY', '11005'),
#  (1010309, 'Richard', 'Uribe', '11703 East 16th Street', 'Floral Park', 'NY', '11005'),
#  (1060754, 'Hilda', 'Weston', '11703 East 16th Street', 'Floral Park', 'NY', '11005'),
#  (1179550, 'Inez', 'Huffman', '2129 East 21st Street', 'Florida', 'NY', '10921'),
#  (1075840, 'Kristine', 'Parson', '2129 East 21st Street', 'Florida', 'NY', '10921'),
#  (1147875, 'Guy', 'Will', '2129 East 21st Street', 'Florida', 'NY', '10921'),
#  (1120818, 'Corey', 'Garcia', '20806 West 24th Street', 'Flushing', 'NY', '11352'),
#  (1138389, 'Michael', 'Guinn', '20806 West 24th Street', 'Flushing', 'NY', '11352'),
#  (1000486, 'Neil', 'Haywood', '1252 Windsor Street', 'Flushing', 'NY', '11351'),
#  (1059236, 'John', 'Stevens', '20489 East 24th Street', 'Flushing', 'NY', '11390'),
#  (1033725, 'Humberto', 'Trimble', '1819 West Edwards Road', 'Flushing', 'NY', '11381'),
#  (1151281, 'Chadwick', 'Clark', '20224 West 13th Street', 'Fly Creek', 'NY', '13337'),
#  (1076596, 'Jeffrey', 'Benavides', '10120 West 12th Street', 'Forestville', 'NY', '14062'),
#  (1167998, 'Rachel', 'Masters', '18711 East 4th Street', 'Forestville', 'NY', '14062'),
#  (1134950, 'Christopher', 'Muniz', '18711 East 4th Street', 'Forestville', 'NY', '14062'),
#  (1087171, 'Marie', 'Zelaya', '10120 West 12th Street', 'Forestville', 'NY', '14062'),
#  (1171187, 'Norris', 'Franks', '20869 North 25th Street', 'Fort Ann', 'NY', '12827'),
#  (1060065, 'Tyson', 'Goetz', '1631 Brentwood Road', 'Fort Ann', 'NY', '12827'),
#  (1006045, 'Maria', 'Krug', '20869 North 25th Street', 'Fort Ann', 'NY', '12827'),
#  (1164137, 'Verna', 'Sampson', '15491 West 10th Street', 'Fort Edward', 'NY', '12828'),
#  (1127643, 'Barbara', 'Sanchez', '2211 West 13th Street', 'Fort Edward', 'NY', '12828'),
#  (1009547, 'Tanya', 'Vernon', '2211 West 13th Street', 'Fort Edward', 'NY', '12828'),
#  (1141927, 'William', 'Soares', '1843 Warren Parkway', 'Fort Hunter', 'NY', '12069'),
#  (1018711, 'Antonio', 'Wesson', '1843 Warren Parkway', 'Fort Hunter', 'NY', '12069'),
#  (1121548, 'Seymour', 'Carlson', '1629 West 18th Street', 'Fort Montgomery', 'NY', '10922'),
#  (1144682, 'Denny', 'Kwon', '1201 East Willow Avenue', 'Fort Montgomery', 'NY', '10922'),
#  (1035465, 'Tanya', 'Jones', '1107 Linden Street', 'Fort Plain', 'NY', '13339'),
#  (1061797, 'Tamara', 'Reitz', '176 Ridgeline Road', 'Franklin Square', 'NY', '11010'),
#  (1200381, 'Madeline', 'Thornton', '176 Ridgeline Road', 'Franklin Square', 'NY', '11010'),
#  (1032178, 'Benjamin', 'Acevedo', '1973 East 8th Street', 'Fremont Center', 'NY', '12736'),
#  (1088150, 'Stefan', 'Bogart', '1973 East 8th Street', 'Fremont Center', 'NY', '12736'),
#  (1057433, 'Irma', 'Becker', '1322 Carondelet Highway', 'Fresh Meadows', 'NY', '11365'),
#  (1062673, 'Margaret', 'Chamberlain', '19780 West 10th Street', 'Fresh Meadows', 'NY', '11365'),
#  (1117482, 'Jane', 'Gross', '186 West 17th Street', 'Fresh Meadows', 'NY', '11365'),
#  (1030742, 'Frank', 'Rowe', '186 West 17th Street', 'Fresh Meadows', 'NY', '11365'),
#  (1200508, 'Herbert', 'Meehan', '10987 West 3rd Street', 'Friendship', 'NY', '14739'),
#  (1018233, 'Michael', 'Parker', '10987 West 3rd Street', 'Friendship', 'NY', '14739'),
#  (1145650, 'Jana', 'Lozano', '12183 North 23rd Street', 'Fulton', 'NY', '13069'),
#  (1031250, 'Annie', 'Blackmon', '19935 East 12th Street', 'Gansevoort', 'NY', '12831'),
#  (1046369, 'Sammy', 'Burger', '19935 East 12th Street', 'Gansevoort', 'NY', '12831'),
#  (1109892, 'Denise', 'Silva', '19935 East 12th Street', 'Gansevoort', 'NY', '12831'),
#  (1059363, 'Yvette', 'Blankenship', '218 North 10th Street', 'Garden City', 'NY', '11530'),
#  (1044409, 'Doris', 'England', '218 North 10th Street', 'Garden City', 'NY', '11530'),
#  (1196972, 'Rosalyn', 'Fletcher', '1680 North 22nd Street', 'Garden City', 'NY', '11535'),
#  (1112800, 'Faye', 'Hamilton', '1233 West University Road', 'Garden City', 'NY', '11599'),
#  (1031828, 'Rosie', 'Lund', '1434 North 16th Street', 'Garden City', 'NY', '11599'),
#  (1131761, 'Harold', 'Mortensen', '1680 North 22nd Street', 'Garden City', 'NY', '11535'),
#  (1109575, 'Joe', 'Muir', '17828 West 21st Street', 'Garnerville', 'NY', '10923'),
#  (1105427, 'Seth', 'Rupp', '1213 East Garvey Parkway', 'Geneva', 'NY', '14456'),
#  (1124559, 'John', 'Durant', '1714 West 11th Street', 'Genoa', 'NY', '13071'),
# ...
#  (1143894, 'Joaquin', 'Lunsford', '1807 Columbia Parkway', 'Leicester', 'NY', '14481'),
#  (1120639, 'Stephen', 'Sutton', '1807 Columbia Parkway', 'Leicester', 'NY', '14481'),
#  (1017775, 'Maynard', 'Tyler', '2167 North 18th Street', 'Leicester', 'NY', '14481'),
#  (1017027, 'Bethany', 'Paine', '10475 West 22nd Street', 'Leon', 'NY', '14751'),
#  (1011451, 'Mary', 'Noble', '1960 Elm Boulevard', 'Lewis', 'NY', '12950'),
#  (1198244, 'Randy', 'Robichaud', '1960 Elm Boulevard', 'Lewis', 'NY', '12950'),
#  (1124763, 'Christina', 'Robb', '1073 West Pecan Street', 'Lewiston', 'NY', '14092'),
#  (1153472, 'Wilma', 'Christy', '128 East Cass Road', 'Liberty', 'NY', '12754'),
#  (1076098, 'Scott', 'Hassan', '2044 West Reed Road', 'Lindenhurst', 'NY', '11757'),
#  (1036821, 'Adam', 'Bell', '21106 East 8th Street', 'Lindley', 'NY', '14858'),
#  (1167610, 'Craig', 'Mckeown', '21106 East 8th Street', 'Lindley', 'NY', '14858'),
#  (1061796, 'Mary', 'Mota', '1439 West Poplar Boulevard', 'Lisle', 'NY', '13797'),
#  (1166926, 'Jimmy', 'Shepherd', '1439 West Poplar Boulevard', 'Lisle', 'NY', '13797'),
#  (1003407, 'Brian', 'Gallardo', '22385 West 12th Street', 'Little Genesee', 'NY', '14754'),
#  (1020496, 'Patricia', 'Gant', '1097 Norton Street', 'Little Neck', 'NY', '11362'),
#  (1019923, 'Rocco', 'Gaylord', '19167 East 19th Street', 'Little Neck', 'NY', '11363'),
#  (1036131, 'Guy', 'Meadows', '1398 Front Road', 'Little Neck', 'NY', '11363'),
#  (1042546, 'Kelvin', 'Fletcher', '1025 East Jersey Street', 'Little York', 'NY', '13087'),
#  (1128983, 'Gary', 'Redding', '1025 East Jersey Street', 'Little York', 'NY', '13087'),
#  (1106767, 'Todd', 'Allen', '1507 North McKinley Drive', 'Livonia', 'NY', '14487'),
#  (1091759, 'Phyllis', 'Ball', '17969 West 7th Street', 'Livonia', 'NY', '14487'),
#  (1023893, 'Wanda', 'Young', '17969 West 7th Street', 'Livonia', 'NY', '14487'),
#  (1093320, 'Clarence', 'Bennett', '10933 West 12th Street', 'Loch Sheldrake', 'NY', '12759'),
#  (1127177, 'Robbie', 'Hess', '13987 East 15th Street', 'Loch Sheldrake', 'NY', '12759'),
#  (1129466, 'Emmanuel', 'Arena', '1258 North 12th Street', 'Lockport', 'NY', '14094'),
#  (1029366, 'Ethan', 'Churchill', '2100 East 15th Street', 'Lockport', 'NY', '14094'),
#  (1051677, 'Elliot', 'Moore', '1258 North 12th Street', 'Lockport', 'NY', '14094'),
#  (1066320, 'Elliot', 'Mohamed', '1756 East 18th Street', 'Locust Valley', 'NY', '11560'),
#  (1139555, 'Patricia', 'Lightfoot', '1380 East 16th Street', 'Long Eddy', 'NY', '12760'),
#  (1157985, 'Stacey', 'Beck', '1549 East 7th Street', 'Long Island City', 'NY', '11120'),
#  (1093725, 'Rebecca', 'Domingo', '1331 Blue Road', 'Long Island City', 'NY', '11120'),
#  (1171725, 'Rosa', 'Harvey', '1701 North Snowden Boulevard', 'Long Island City', 'NY', '11101'),
#  (1098953, 'Scott', 'Lumpkin', '1331 Blue Road', 'Long Island City', 'NY', '11120'),
#  (1070494, 'Tina', 'Morrison', '1549 East 7th Street', 'Long Island City', 'NY', '11120'),
#  (1201263, 'Dean', 'Read', '1701 North Snowden Boulevard', 'Long Island City', 'NY', '11101'),
#  (1029616, 'Marla', 'Boylan', '1067 Ames Road', 'Lowman', 'NY', '14861'),
#  (1163532, 'Gabriela', 'Cobb', '1067 Ames Road', 'Lowman', 'NY', '14861'),
#  (1132493, 'Frances', 'Robbins', '1067 Ames Road', 'Lowman', 'NY', '14861'),
#  (1115831, 'Timothy', 'Farina', '1752 Carondelet Drive', 'Lowville', 'NY', '13367'),
#  (1182206, 'Amber', 'Neal', '1752 Carondelet Drive', 'Lowville', 'NY', '13367'),
#  (1094558, 'Kenneth', 'Qualls', '1752 Carondelet Drive', 'Lowville', 'NY', '13367'),
#  (1187815, 'Mary', 'Bishop', '1972 West 5th Street', 'Lynbrook', 'NY', '11564'),
#  (1060898, 'Frederick', 'Barlow', '19392 North 8th Street', 'Lyndonville', 'NY', '14098'),
#  (1150181, 'Andrea', 'Burleson', '19392 North 8th Street', 'Lyndonville', 'NY', '14098'),
#  (1081834, 'Howard', 'Wagoner', '19392 North 8th Street', 'Lyndonville', 'NY', '14098'),
#  (1178417, 'Wanda', 'Lowman', '21493 East 18th Street', 'Macedon', 'NY', '14502'),
#  (1127522, 'Johnny', 'Redman', '21493 East 18th Street', 'Macedon', 'NY', '14502'),
#  (1138511, 'Bonnie', 'Sosa', '21493 East 18th Street', 'Macedon', 'NY', '14502'),
#  (1074560, 'Timothy', 'Boswell', '18479 North 2nd Street', 'Machias', 'NY', '14101'),
#  (1176687, 'Marshall', 'Bullard', '161 East 21st Street', 'Madrid', 'NY', '13660'),
#  (1089790, 'Sean', 'Gutierrez', '161 East 21st Street', 'Madrid', 'NY', '13660'),
#  (1015279, 'Freda', 'Heard', '1335 24th Street', 'Madrid', 'NY', '13660'),
#  (1172267, 'Maxwell', 'Brennan', '2072 3rd Street', 'Mahopac', 'NY', '10541'),
#  (1187307, 'Margie', 'Espino', '2072 3rd Street', 'Mahopac', 'NY', '10541'),
#  (1110467, 'Ramona', 'Halstead', '2072 3rd Street', 'Mahopac', 'NY', '10541'),
#  (1145882, 'Ruth', 'Parra', '1725 East 5th Street', 'Malden On Hudson', 'NY', '12453'),
#  (1163768, 'Charles', 'Larsen', '14878 North 2nd Street', 'Malverne', 'NY', '11565'),
#  (1019992, 'Margaret', 'Francis', '22120 North 2nd Street', 'Mamaroneck', 'NY', '10543'),
#  (1080912, 'Kathleen', 'Ratcliff', '1899 Bradford Drive', 'Manhasset', 'NY', '11030'),
#  (1139262, 'Patty', 'Rowley', '1039 West 12th Street', 'Manlius', 'NY', '13104'),
#  (1111668, 'Eugene', 'Cameron', '1577 North Field Highway', 'Maple Springs', 'NY', '14756'),
#  (1012425, 'Theresa', 'Younger', '12214 North 19th Street', 'Marcy', 'NY', '13403'),
#  (1139057, 'Linda', 'Bain', '1893 East 18th Street', 'Marilla', 'NY', '14102'),
#  (1044419, 'Franklin', 'Mcdonough', '1902 East Ridgeline Circle', 'Martville', 'NY', '13111'),
#  (1107954, 'Rachel', 'Thornton', '1902 East Ridgeline Circle', 'Martville', 'NY', '13111'),
#  (1093152, 'Theresa', 'Hair', '2238 North 2nd Street', 'Maryland', 'NY', '12116'),
#  (1039134, 'Felicia', 'Ashley', '1176 North 5th Street', 'Massapequa', 'NY', '11758'),
#  (1179209, 'Philip', 'Harlow', '1176 North 5th Street', 'Massapequa', 'NY', '11758'),
#  (1031597, 'William', 'Rush', '1685 East 14th Street', 'Massapequa Park', 'NY', '11762'),
#  (1101861, 'Dominick', 'Peters', '169 West 15th Street', 'Massena', 'NY', '13662'),
#  (1004344, 'Brandon', 'Alessi', '131 Hanley Street', 'Maybrook', 'NY', '12543'),
#  (1188584, 'Nicole', 'Laughlin', '131 Hanley Street', 'Maybrook', 'NY', '12543'),
#  (1164638, 'Jose', 'Lawton', '1292 North Wells Road', 'Maybrook', 'NY', '12543'),
#  (1131550, 'Walter', 'Richardson', '1292 North Wells Road', 'Maybrook', 'NY', '12543'),
#  (1029960, 'Sara', 'Black', '14819 14th Street', 'Mc Donough', 'NY', '13801'),
#  (1029201, 'Leonard', 'Chin', '19295 West 7th Street', 'Mc Donough', 'NY', '13801'),
#  (1056940, 'Norma', 'Flanigan', '14819 14th Street', 'Mc Donough', 'NY', '13801'),
#  (1133885, 'Ruby', 'Lofton', '16904 East 18th Street', 'Mc Donough', 'NY', '13801'),
#  (1118728, 'Joseph', 'Brooks', '1953 West Manchester Street', 'Mecklenburg', 'NY', '14863'),
#  (1015216, 'Pamela', 'Mora', '1953 West Manchester Street', 'Mecklenburg', 'NY', '14863'),
#  (1180150, 'Robin', 'Huey', '22070 West 18th Street', 'Medusa', 'NY', '12120'),
#  (1092325, 'Beth', 'Duda', '1920 West Taylor Street', 'Mellenville', 'NY', '12544'),
#  (1023616, 'Leah', 'Waller', '195 East Fillmore Road', 'Mellenville', 'NY', '12544'),
#  (1127978, 'Heather', 'Guerra', '174 Lowell Avenue', 'Melrose', 'NY', '12121'),
#  (1022784, 'Rose', 'Kopp', '1170 East 2nd Street', 'Melrose', 'NY', '12121'),
#  (1186932, 'William', 'Sandoval', '1170 East 2nd Street', 'Melrose', 'NY', '12121'),
#  (1195049, 'Jamal', 'Ayala', '1339 Prospect Street', 'Melville', 'NY', '11747'),
#  (1083856, 'Kathleen', 'Estrada', '217 West 4th Street', 'Melville', 'NY', '11775'),
#  (1037187, 'Linda', 'Joyce', '1339 Prospect Street', 'Melville', 'NY', '11747'),
#  (1073908, 'Wallace', 'Lynch', '217 West 4th Street', 'Melville', 'NY', '11775'),
#  (1096937, 'Ned', 'Manion', '217 West 4th Street', 'Melville', 'NY', '11775'),
#  (1041695, 'Brenda', 'Patterson', '21455 East 5th Street', 'Melville', 'NY', '11775'),
#  (1002036, 'James', 'Weir', '21455 East 5th Street', 'Melville', 'NY', '11775'),
#  (1119193, 'Philip', 'Bush', '15756 North 24th Street', 'Memphis', 'NY', '13112'),
#  (1082992, 'Ralph', 'Gervais', '15756 North 24th Street', 'Memphis', 'NY', '13112'),
#  (1119697, 'Michael', 'Jester', '15756 North 24th Street', 'Memphis', 'NY', '13112'),
#  (1118754, 'Michael', 'Distefano', '210 West Van Buren Road', 'Mendon', 'NY', '14506'),
#  (1093682, 'Bessie', "O'Neill", '210 West Van Buren Road', 'Mendon', 'NY', '14506'),
#  (1028703, 'Beverly', 'Means', '1509 Fairbanks Road', 'Meridian', 'NY', '13113'),
#  (1155431, 'Elizabeth', 'Ray', '1027 East Allen Road', 'Mexico', 'NY', '13114'),
#  (1028396, 'Julia', 'Baez', '1105 Harris Street', 'Middle Falls', 'NY', '12848'),
#  (1065206, 'Randall', 'Vail', '1162 Lake Road', 'Middle Grove', 'NY', '12850'),
#  (1133980, 'Keri', 'Beverly', '1197 Humphrey Road', 'Middle Island', 'NY', '11953'),
#  (1118416, 'Norbert', 'Longoria', '1837 North 16th Street', 'Middleport', 'NY', '14105'),
#  (1119363, 'Pamela', 'Ponder', '12 Charles Road', 'Middleport', 'NY', '14105'),
#  (1106943, 'Michael', 'Gamez', '1181 Bay Highway', 'Middlesex', 'NY', '14507'),
#  (1067309, 'Christina', 'Partin', '1181 Bay Highway', 'Middlesex', 'NY', '14507'),
#  (1071541, 'Laura', 'Huff', '19875 West 13th Street', 'Middletown', 'NY', '10941'),
#  (1155616, 'Gwen', 'Johnston', '15048 North 4th Street', 'Middletown', 'NY', '10941'),
#  (1195008, 'Muriel', 'Woody', '1333 East 7th Street', 'Middletown', 'NY', '10943'),
#  (1151402, 'Marilyn', 'Franklin', '11707 West 4th Street', 'Middleville', 'NY', '13406'),
#  (1188867, 'Judy', 'Romo', '20862 East 17th Street', 'Milford', 'NY', '13807'),
#  (1112568, 'Winston', 'Fair', '14304 East 18th Street', 'Millerton', 'NY', '12546'),
#  (1195168, 'Wayne', 'Fry', '17537 East 8th Street', 'Minerva', 'NY', '12851'),
#  (1058681, 'Darin', 'Peacock', '17537 East 8th Street', 'Minerva', 'NY', '12851'),
#  (1074042, 'Barbara', 'Wade', '15453 North 21st Street', 'Minoa', 'NY', '13116'),
#  (1047124, 'Louise', 'Alexander', '1093 North Bennett Drive', 'Monsey', 'NY', '10952'),
#  (1055000, 'Norma', 'Carlton', '1093 North Bennett Drive', 'Monsey', 'NY', '10952'),
#  (1132320, 'Lori', 'Bradbury', '1967 West 22nd Street', 'Montauk', 'NY', '11954'),
#  (1034949, 'Kimberly', 'Bueno', '1621 East Broadway Street', 'Monticello', 'NY', '12701'),
#  (1018337, 'Charles', 'King', '1621 East Broadway Street', 'Monticello', 'NY', '12701'),
#  (1111368, 'Melanie', 'Mark', '22 Alley Avenue', 'Monticello', 'NY', '12701'),
#  (1019775, 'John', 'Cumming', '2010 West 1st Street', 'Mooers Forks', 'NY', '12959'),
#  (1026010, 'Claire', 'Gee', '13 North 22nd Street', 'Mooers Forks', 'NY', '12959'),
#  (1059956, 'Gayle', 'Pease', '1873 West 13th Street', 'Moravia', 'NY', '13118'),
#  (1074865, 'Maureen', 'Stoll', '1873 West 13th Street', 'Moravia', 'NY', '13118'),
#  (1155519, 'Ted', 'Morse', '1228 North Bristlecone Road', 'Moriah Center', 'NY', '12961'),
#  (1126843, 'Martin', 'Raymond', '12247 West 24th Street', 'Morris', 'NY', '13808'),
#  (1123890, 'Louis', 'Griffith', '14350 West 20th Street', 'Morrisonville', 'NY', '12962'),
#  (1124525, 'Jeanette', 'Bryant', '1707 West Foster Road', 'Mottville', 'NY', '13119'),
#  (1154552, 'Tamara', 'Hartwig', '19936 North 7th Street', 'Mottville', 'NY', '13119'),
#  (1121622, 'Stanley', 'Villarreal', '1707 West Foster Road', 'Mottville', 'NY', '13119'),
#  (1144960, 'Frank', 'Carranza', '1746 East 22nd Street', 'Mount Marion', 'NY', '12456'),
#  (1123802, 'Walter', 'Larsen', '1746 East 22nd Street', 'Mount Marion', 'NY', '12456'),
#  (1180259, 'Douglas', 'Claar', '1531 North Wheeler Avenue', 'Mount Sinai', 'NY', '11766'),
#  (1053630, 'Ernesto', 'Krueger', '1531 North Wheeler Avenue', 'Mount Sinai', 'NY', '11766'),
#  (1155587, 'Dean', 'Mcgregor', '1531 North Wheeler Avenue', 'Mount Sinai', 'NY', '11766'),
#  (1111183, 'Mathew', 'Abbott', '1406 East 14th Street', 'Mount Upton', 'NY', '13809'),
#  (1090644, 'William', 'Grace', '2208 North 11th Street', 'Mount Upton', 'NY', '13809'),
#  (1107121, 'Nancy', 'Randolph', '2109 East 16th Street', 'Mount Upton', 'NY', '13809'),
#  (1155097, 'Israel', 'Berry', '18143 West 15th Street', 'Mount Vernon', 'NY', '10558'),
#  (1017391, 'Kathleen', 'Church', '18143 West 15th Street', 'Mount Vernon', 'NY', '10558'),
#  (1015939, 'Timothy', 'Ely', '1008 East Victoria Road', 'Mount Vernon', 'NY', '10551'),
#  (1182898, 'Marty', 'Granger', '1289 Maryland Road', 'Mount Vernon', 'NY', '10559'),
#  (1058007, 'Thomas', 'Horton', '18143 West 15th Street', 'Mount Vernon', 'NY', '10558'),
#  (1192024, 'Gregg', 'Lord', '1289 Maryland Road', 'Mount Vernon', 'NY', '10559'),
#  (1123067, 'Elizabeth', 'Tipton', '18143 West 15th Street', 'Mount Vernon', 'NY', '10558'),
#  (1141616, 'Jan', 'Bigelow', '16962 North 10th Street', 'Mountainville', 'NY', '10953'),
#  (1067990, 'Jose', 'Marshall', '16962 North 10th Street', 'Mountainville', 'NY', '10953'),
#  (1188615, 'Wiley', 'Mata', '1710 North 5th Street', 'Napanoch', 'NY', '12458'),
#  (1185220, 'Bernardo', 'Strong', '1710 North 5th Street', 'Napanoch', 'NY', '12458'),
#  (1011346, 'Robert', 'Orr', '20937 West 5th Street', 'Naples', 'NY', '14512'),
#  (1130430, 'Luz', 'Whitlock', '20937 West 5th Street', 'Naples', 'NY', '14512'),
#  (1166256, 'Carolyn', 'Wise', '20937 West 5th Street', 'Naples', 'NY', '14512'),
#  (1155964, 'Mabel', 'Sheppard', '12712 15th Street', 'Narrowsburg', 'NY', '12764'),
#  (1175204, 'Rafael', 'Nash', '1319 North Medlar Road', 'Nassau', 'NY', '12123'),
#  (1113032, 'Mary', 'Short', '18691 East 8th Street', 'Nassau', 'NY', '12123'),
#  (1157146, 'Beverly', 'Baugh', '1627 North Beale Avenue', 'Nedrow', 'NY', '13120'),
#  (1029644, 'Ruth', 'Faust', '1627 North Beale Avenue', 'Nedrow', 'NY', '13120'),
#  (1186319, 'Michael', 'Guidry', '1297 East Prospect Avenue', 'Nedrow', 'NY', '13120'),
#  (1088072, 'Van', 'Hough', '1297 East Prospect Avenue', 'Nedrow', 'NY', '13120'),
#  (1095012, 'Darin', 'Lehman', '1627 North Beale Avenue', 'Nedrow', 'NY', '13120'),
#  (1015915, 'George', 'Boisvert', '1827 East 3rd Street', 'Neversink', 'NY', '12765'),
#  (1100643, 'Randolph', 'Bates', '1002 West College Boulevard', 'New Berlin', 'NY', '13411'),
#  (1000472, 'Roger', 'Wood', '1002 West College Boulevard', 'New Berlin', 'NY', '13411'),
#  (1043505, 'Theodore', 'Colvin', '1671 West 12th Street', 'New Hampton', 'NY', '10958'),
#  (1152848, 'Janice', 'Enos', '16640 North 11th Street', 'New Hampton', 'NY', '10958'),
#  (1195297, 'Martha', 'Pena', '1671 West 12th Street', 'New Hampton', 'NY', '10958'),
#  (1176776, 'David', 'Yee', '16640 North 11th Street', 'New Hampton', 'NY', '10958'),
#  (1144168, 'Kevin', 'Dodge', '19175 East 24th Street', 'New Haven', 'NY', '13121'),
#  (1143438, 'Cynthia', 'Lapointe', '1843 North Oakland Highway', 'New Hyde Park', 'NY', '11041'),
#  (1132836, 'Desmond', 'Centeno', '17515 19th Street', 'New Kingston', 'NY', '12459'),
#  (1032189, 'Julie', 'Franks', '17515 19th Street', 'New Kingston', 'NY', '12459'),
#  (1184916, 'Raquel', 'Koehler', '1503 East Holly Highway', 'New Kingston', 'NY', '12459'),
#  (1177152, 'Peter', 'Li', '1440 Claypool Road', 'New Rochelle', 'NY', '10801'),
#  (1191182, 'Jodi', 'Palumbo', '1458 Carter Drive', 'New Rochelle', 'NY', '10801'),
#  (1093721, 'Jackson', 'Stephenson', '1440 Claypool Road', 'New Rochelle', 'NY', '10801'),
#  (1106496, 'Jennifer', 'Hitchcock', '11317 West 3rd Street', 'New Russia', 'NY', '12964'),
#  (1035118, 'Sandra', 'Heffner', '1887 West Wesson Boulevard', 'New Suffolk', 'NY', '11956'),
#  (1146439, 'Rolando', 'Doane', '164 4th Street', 'New Woodstock', 'NY', '13122'),
#  (1036305, 'James', 'Driscoll', '1545 Foster Drive', 'New Woodstock', 'NY', '13122'),
#  (1079855, 'Frankie', 'Fortin', '164 4th Street', 'New Woodstock', 'NY', '13122'),
#  (1174053, 'Claudia', 'Alston', '1824 North Miller Street', 'New York', 'NY', '10060'),
#  (1023517, 'Maria', 'Arbogast', '1179 North 24th Street', 'New York', 'NY', '10032'),
#  (1134226, 'Dorothy', 'Avery', '146 Lakeview Place', 'New York', 'NY', '10027'),
#  (1105292, 'Cedric', 'Bacon', '1121 North 20th Street', 'New York', 'NY', '10012'),
#  (1018969, 'Timothy', 'Baker', '1243 West 17th Street', 'New York', 'NY', '10107'),
#  ...]

# %% [markdown]
# ## Example 7: Pattern Matching and Range Filtering
#
# Suppose we wanted to retrieve products with prices falling within a specific price range (say 4500 and 7500) andbelongiong to certain brands.
#
# We can solve this query in two steps:
# 1. Identify the brands that you wnat to use as a filter.
# 2. Apply the price range filter on the products from those brands.
#
# Let's see both of them, one by one.

# %% [markdown]
# **Step 1: Identify the product brands**
#
# Make use of the DISTINCT keyword to retrieve all the brands from the products dataset.

# %%
# %%sql
#
# SELECT DISTINCT brand
# FROM products
# ORDER BY brand;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 47 rows affected.
# [('ACME',),
#  ('ARCAM',),
#  ('Argo',),
#  ('Artie',),
#  ('BDT',),
#  ('Bigdeal',),
#  ('Bitbucket',),
#  ('Bitmonkey',),
#  ('BuckLogix',),
#  ('Bytefortress',),
#  ('Byteweasel',),
#  ('Chatter Audio',),
#  ('Chestnut',),
#  ('DevNull',),
#  ('Dorx',),
#  ('Dualcore',),
#  ('Duff',),
#  ('ElCheapo',),
#  ('Electrosaurus',),
#  ('Foocorp',),
#  ('Gigabux',),
#  ('Homertech',),
#  ('Krustybitz',),
#  ('Lemmon',),
#  ('McDowell',),
#  ('Megachango',),
#  ('Olde-Gray',),
#  ('Orion',),
#  ('Overtop',),
#  ('Sparky',),
#  ('Spindown',),
#  ('Sprite',),
#  ('SuperGamer',),
#  ('Terrapin Sands',),
#  ('Texi',),
#  ('Tortoise',),
#  ('TPS',),
#  ('Tyrell',),
#  ('Ultramegaco',),
#  ('United Digistuff',),
#  ('Weebits',),
#  ('Weisenheimer',),
#  ('Wernham',),
#  ('Whiteacre',),
#  ('Wolfpack',),
#  ('XYZ',),
#  ('Yoyodyne',)]

# %% [markdown]
# Let's say we want to find products from the brands that start with letters 'C', 'D', and 'U'.

# %%
# %%sql
#
# SELECT prod_id, brand, name, price
# FROM products
# WHERE brand LIKE 'C%' OR brand LIKE 'D%' OR brand LIKE 'U%'
# ORDER BY brand;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 283 rows affected.
# [(1274042, 'Chatter Audio', 'Multimedia Headset', 5739),
#  (1274045, 'Chatter Audio', 'Multimedia Headset', 5529),
#  (1274056, 'Chatter Audio', 'Portable CD Player', 4099),
#  (1274061, 'Chatter Audio', 'Stereo Component CD Player', 19869),
#  (1274079, 'Chatter Audio', 'MP3 Player (16 GB internal memory)', 12619),
#  (1274088, 'Chatter Audio', 'MP3 Player (16 GB internal memory)', 12609),
#  (1274090, 'Chatter Audio', 'MP3 Player (32 GB internal memory)', 18669),
#  (1274091, 'Chatter Audio', 'MP3 Player (32 GB internal memory)', 17999),
#  (1274105, 'Chatter Audio', 'Microphone (model U47)', 18439),
#  (1273773, 'Chestnut', 'Rechargeable Batteries (D, 2 pack)', 2039),
#  (1274004, 'Chestnut', 'S-Video Female-to-Female Cable (24 in.)', 1549),
#  (1273917, 'Chestnut', 'RCA Phono Male to Mini Female Adapter', 419),
#  (1273889, 'Chestnut', 'USB 3.0 4-Port Ultra Mini Hub', 4679),
#  (1273887, 'Chestnut', 'USB 3.0 4-Port Ultra Mini Hub', 4079),
#  (1273926, 'Chestnut', 'RCA Phono Female to Female, Barrel Adapter', 469),
#  (1273691, 'Chestnut', 'Case for Notebook Computer', 4839),
#  (1273864, 'Chestnut', 'Extension cord (60 in.)', 2389),
#  (1274459, 'Chestnut', 'Digital Video Recorder (2.0 TB)', 60519),
#  (1273862, 'Chestnut', 'Extension cord (36 in., heavy duty)', 2849),
#  (1274435, 'Chestnut', 'Blu-Ray Player', 12529),
#  (1274424, 'Chestnut', '48" Wide Screen TV', 70939),
#  (1273720, 'Chestnut', 'Executive Stylus and Pen', 4849),
#  (1273721, 'Chestnut', '6-cell Battery', 4019),
#  (1273859, 'Chestnut', 'Extension cord (36 in., heavy duty)', 2919),
#  (1273726, 'Chestnut', '8-cell Battery', 6549),
#  (1274414, 'Chestnut', '42" Wide Screen TV', 59789),
#  (1273728, 'Chestnut', 'Compact Charger', 3529),
#  (1273936, 'Chestnut', '3.5mm Mini Female to Female, Barrel Adapter', 319),
#  (1274399, 'Chestnut', '27" Wide Screen TV', 27589),
#  (1273946, 'Chestnut', '3-Pin XLR Female to Female, Barrel Adapter', 859),
#  (1273952, 'Chestnut', '1/4 in. Standard Phone Male to 3.5mm Mini Female Adapter', 299),
#  (1273953, 'Chestnut', '1/4 in. Standard Phone Male to 3.5mm Mini Female Adapter', 289),
#  (1273742, 'Chestnut', 'Batteries (AA, 4 pack)', 729),
#  (1273745, 'Chestnut', 'Batteries (AAA, 4 pack)', 759),
#  (1273974, 'Chestnut', 'F Jack Male-to-Male Cable (18 in.)', 1369),
#  (1273983, 'Chestnut', 'F Jack Male-to-Male Cable (36 in.)', 2019),
#  (1273990, 'Chestnut', 'Phono Jack to BNC Plug', 539),
#  (1273796, 'Chestnut', 'Wired mouse (three button)', 4199),
#  (1273792, 'Chestnut', 'Keyboard (wireless, with nub)', 13709),
#  (1273785, 'Chestnut', 'Keyboard (basic PC104)', 3649),
#  (1274005, 'Chestnut', 'S-Video Female-to-Female Cable (24 in.)', 1439),
#  (1274013, 'Chestnut', '8GB DDR3-1333 (PC3-10600) Desktop Memory Kit (2x4GB)', 49),
#  (1273641, 'Chestnut', 'USB Card Reader', 1839),
#  (1274027, 'DevNull', '4GB DDR3-1333 (PC3-10600) Desktop Memory Kit (2x2GB)', 39),
#  (1274747, 'DevNull', '32 GB Micro SD', 6059),
#  (1274639, 'DevNull', '2.0 TB SATA3 Disk', 14289),
#  (1273774, 'DevNull', 'Rechargeable Batteries (D, 2 pack)', 2029),
#  (1274011, 'DevNull', '8GB DDR3-1333 (PC3-10600) Desktop Memory Kit (2x4GB)', 59),
#  (1273758, 'DevNull', 'Batteries (D, 2 pack)', 989),
#  (1274746, 'DevNull', '16 GB Micro SD (High Performance)', 5619),
#  (1274606, 'DevNull', '9.1 GB SCSI Disk', 8229),
#  (1273646, 'DevNull', 'USB Card Reader', 1929),
#  (1274738, 'DevNull', '8 GB Micro SD', 2849),
#  (1274001, 'DevNull', 'S-Video Female-to-Female Cable (12 in.)', 849),
#  (1273993, 'DevNull', 'Phono Jack to UHF Plug', 599),
#  (1273805, 'DevNull', 'Trackball', 4949),
#  (1274711, 'DevNull', '64 GB SSD Disk', 21509),
#  (1273989, 'DevNull', 'F Jack Male-to-Male Cable (72 in.)', 2849),
#  (1273819, 'DevNull', 'Battery Charger', 3199),
#  (1273827, 'DevNull', 'UPS 1500 Watt', 17289),
#  (1274699, 'DevNull', '500 GB Portable External USB 2.0 Disk', 8299),
#  (1273838, 'DevNull', 'UPS 500 Watt', 8699),
#  (1273981, 'DevNull', 'F Jack Male-to-Male Cable (36 in.)', 1909),
#  (1273843, 'DevNull', 'Surge Protector (6-Outlet)', 2109),
#  (1274657, 'DevNull', '8 GB USB Flash Drive ', 2849),
#  (1273966, 'DevNull', 'Phono Plug to F Jack', 629),
#  (1273965, 'DevNull', 'Phono Plug to F Jack', 599),
#  (1273961, 'DevNull', 'Phono Plug to UHF Jack', 549),
#  (1273739, 'DevNull', 'Batteries (AA, 2 pack)', 399),
#  (1274649, 'DevNull', '3.0 TB SATA3 Disk', 18379),
#  (1273737, 'DevNull', 'Batteries (AA, 2 pack)', 389),
#  (1273939, 'DevNull', '3.5mm Mini Female to Female, Barrel Adapter', 299),
#  (1273855, 'DevNull', 'Extension cord (36 in.)', 2029),
#  (1273729, 'DevNull', 'Compact Charger', 4139),
#  (1273857, 'DevNull', 'Extension cord (36 in.)', 1979),
#  (1273933, 'DevNull', 'RCA Phono Male to 1/4 in. Standard Phone Female Adapter', 579),
#  (1273722, 'DevNull', '6-cell Battery', 4599),
#  (1273711, 'DevNull', 'Sleeve for Tablet - Black', 2079),
#  (1274592, 'DevNull', 'Virus Scanner (incl. updates for one year)', 2919),
#  (1273930, 'DevNull', 'RCA Phono Male to 1/4 in. Standard Phone Female Adapter', 609),
#  (1273928, 'DevNull', '3-Pin XLR Male to RCA Phono Female Adapter', 919),
#  (1274593, 'DevNull', 'Virus Scanner (incl. updates for one year)', 2849),
#  (1273921, 'DevNull', 'RCA Phono Male to Mini Female Adapter', 419),
#  (1274594, 'DevNull', 'Virus Scanner (incl. updates for two years)', 3759),
#  (1274595, 'DevNull', 'Virus Scanner (incl. updates for two years)', 3619),
#  (1274602, 'DevNull', 'Office Suite (Enterprise Edition)', 50539),
#  (1273893, 'DevNull', 'USB 4-Port Powered Desktop Hub', 2569),
#  (1273911, 'DevNull', '3.5mm Mini Male to Standard Phone Female', 299),
#  (1273899, 'DevNull', 'Stylus for PDA', 2109),
#  (1273905, 'DevNull', '1/4 in. Standard Phone Female to Female Adapter', 399),
#  (1274034, 'Dorx', 'Basic Headphone', 2029),
#  (1274752, 'Dorx', '64 GB Micro SD', 9859),
#  (1274741, 'Dorx', '16 GB Micro SD', 4329),
#  (1274739, 'Dorx', '8 GB Micro SD', 2839),
#  (1274734, 'Dorx', '8 GB Micro SD', 2959),
#  (1274696, 'Dorx', 'LTO Tape Backup Drive (SCSI)', 79969),
#  (1274689, 'Dorx', '1 TB NAS Server', 16769),
#  (1274686, 'Dorx', '64 GB USB Flash Drive', 8669),
#  (1274676, 'Dorx', '32 GB USB Flash Drive', 5639),
#  (1274665, 'Dorx', '16 GB USB Flash Drive', 4019),
#  (1274663, 'Dorx', '8 GB USB Flash Drive ', 2879),
#  (1274652, 'Dorx', '4 GB USB Flash Drive ', 1929),
#  (1274648, 'Dorx', '3.0 TB SATA3 Disk', 18879),
#  (1274638, 'Dorx', '2.0 TB SATA3 Disk', 14469),
#  (1274609, 'Dorx', 'SCSI Terminator', 4059),
#  (1274603, 'Dorx', '6 GB IDE Disk', 5209),
#  (1274109, 'Dorx', 'Digital Recorder (pocket size)', 8899),
#  (1274104, 'Dorx', 'High-range Premium Speakers', 46699),
#  (1274080, 'Dorx', 'MP3 Player (16 GB internal memory)', 12819),
#  (1274059, 'Dorx', 'Portable CD Player', 4079),
#  (1274049, 'Dorx', 'Stereo USB Headset', 2829),
#  (1273908, 'Dualcore', '3.5mm Mini Male to Standard Phone Female', 299),
#  (1274466, 'Dualcore', 'ADSL Modem + Wireless N Router', 9139),
#  (1274473, 'Dualcore', 'Wireless N Modem Router', 9869),
#  (1273644, 'Dualcore', 'USB Card Reader', 2029),
#  (1273845, 'Dualcore', 'Surge Protector (6-Outlet)', 2209),
#  (1273969, 'Dualcore', 'F Jack Male-to-Male Cable (6 in.)', 649),
#  (1273844, 'Dualcore', 'Surge Protector (6-Outlet)', 2269),
#  (1274743, 'Dualcore', '16 GB Micro SD', 4309),
#  (1273840, 'Dualcore', 'Surge Protector (8-Outlet)', 2429),
#  (1274475, 'Dualcore', 'Wireless G Router', 8249),
#  (1273727, 'Dualcore', 'Compact Charger', 3859),
#  (1273894, 'Dualcore', 'USB 4-Port Powered Desktop Hub', 2619),
#  (1273890, 'Dualcore', 'USB 4-Port Powered Desktop Hub', 2719),
#  (1274735, 'Dualcore', '8 GB Micro SD', 2809),
#  (1273817, 'Dualcore', 'VR Glove', 41529),
#  (1274727, 'Dualcore', '2 GB Micro SD', 979),
#  (1273730, 'Dualcore', 'Compact Charger', 3949),
#  (1274476, 'Dualcore', 'Wireless G Router', 8249),
#  (1274704, 'Dualcore', '750 GB Portable External USB 3.0 Disk', 12409),
#  (1273782, 'Dualcore', 'Keyboard (basic PC101)', 3009),
#  (1274380, 'Dualcore', '24" Wide Screen LCD Monitor', 22719),
#  (1274480, 'Dualcore', 'Wireless N Router', 6889),
#  (1274482, 'Dualcore', 'Wireless N USB Adapter', 6559),
#  (1274498, 'Dualcore', 'VPN Appliance (16 Client license)', 22699),
#  (1274331, 'Dualcore', 'Premium Gamer Desktop', 131539),
#  (1274021, 'Dualcore', '8GB DDR3-1600 (PC3-12800) Dual Channel Desktop Memory Kit (2x4GB)', 119),
#  (1274328, 'Dualcore', 'Professional Series Desktop', 90989),
#  (1274695, 'Dualcore', 'DLT-III Tape Backup Drive (SCSI)', 62179),
#  (1274325, 'Dualcore', 'Basic Desktop', 63409),
#  (1274032, 'Dualcore', 'Basic Headphone', 2049),
#  (1274323, 'Dualcore', 'Home Media Server', 62139),
#  (1274035, 'Dualcore', 'Sports Headphone', 3039),
#  (1274036, 'Dualcore', 'Sports Headphone', 3139),
#  (1274316, 'Dualcore', 'Server (1U rackmount, hex-core, 16GB, 8TB)', 448239),
#  (1274044, 'Dualcore', 'Multimedia Headset', 5609),
#  (1273873, 'Dualcore', 'Extension cord (20 ft., outdoor)', 5049),
#  (1274047, 'Dualcore', 'Multi-Performance PC Headset', 5129),
#  (1274500, 'Dualcore', 'VPN Appliance (50 Clienti license)', 48049),
#  (1274053, 'Dualcore', 'Portable transistor radio (AM/FM)', 3019),
#  (1273757, 'Dualcore', 'Batteries (C, 2 pack)', 739),
#  (1274058, 'Dualcore', 'Portable CD Player', 3819),
#  (1274514, 'Dualcore', 'Network Switch (Gigabit, 8-port)', 6899),
#  (1273931, 'Dualcore', 'RCA Phono Male to 1/4 in. Standard Phone Female Adapter', 559),
#  (1274064, 'Dualcore', 'Stereo Component Turntable', 29419),
#  (1274066, 'Dualcore', 'Stereo Component 8-Track Player', 6919),
#  (1274069, 'Dualcore', 'Portable Cassette Player', 3069),
#  (1274070, 'Dualcore', 'Portable Cassette Player', 2999),
#  (1274072, 'Dualcore', 'MP3 Player (4 GB internal memory)', 7699),
#  (1274077, 'Dualcore', 'MP3 Player (8 GB internal memory)', 9669),
#  (1274529, 'Dualcore', 'Ethernet NIC (Gigabit)', 6139),
#  (1273851, 'Dualcore', 'Extension cord (18 in.)', 1329),
#  (1274083, 'Dualcore', 'MP3 Player (16 GB internal memory)', 13119),
#  (1273754, 'Dualcore', 'Batteries (AAA, 2 pack)', 439),
#  (1274246, 'Dualcore', 'TV Tuner Card (PCI)', 4999),
#  (1274536, 'Dualcore', 'Ethernet NIC (10 Gigabit)', 18939),
#  (1273852, 'Dualcore', 'Extension cord (18 in.)', 1249),
#  (1273680, 'Dualcore', 'High Speed HDMI Cable (72 in.)', 5839),
#  (1273950, 'Dualcore', '1/4 in. Standard Phone Male to 3.5mm Mini Female Adapter', 279),
#  (1273663, 'Dualcore', 'USB Power Adapter (single)', 1259),
#  (1273858, 'Dualcore', 'Extension cord (36 in.)', 1789),
#  (1273664, 'Dualcore', 'Dual USB Power Adapter', 2019),
#  (1274148, 'Dualcore', 'USB 3.0 Front Panel - 2 Port', 1289),
#  (1274165, 'Dualcore', 'Hard Disk Anti-Vibration Screws', 409),
#  (1273666, 'Dualcore', 'Dual USB Power Adapter', 2159),
#  (1274174, 'Dualcore', 'Black 8X BD-ROM 16X DVD-ROM', 7909),
#  (1273854, 'Dualcore', 'Extension cord (36 in.)', 1969),
#  (1274181, 'Dualcore', 'Black 16X DVD-RW', 3519),
#  (1274182, 'Dualcore', 'Black 16X DVD-RW', 3529),
#  (1274635, 'Dualcore', '1.5 TB SATA3 Disk', 13059),
#  (1274634, 'Dualcore', '1.5 TB SATA3 Disk', 12619),
#  (1274633, 'Dualcore', '1.5 TB SATA3 Disk', 13419),
#  (1273853, 'Dualcore', 'Extension cord (18 in.)', 1369),
#  (1274216, 'Dualcore', '3.2GHz CPU', 16229),
#  (1273668, 'Dualcore', 'Dual USB Power Adapter (auto)', 3009),
#  (1274219, 'Dualcore', '3.4GHz CPU', 18059),
#  (1273675, 'Duff', 'High Speed HDMI Cable (48 in.)', 4209),
#  (1273676, 'Duff', 'High Speed HDMI Cable (48 in.)', 4029),
#  (1273738, 'Duff', 'Batteries (AA, 2 pack)', 379),
#  (1273747, 'Duff', 'Batteries (AAA, 4 pack)', 659),
#  (1273753, 'Duff', 'Batteries (AAA, 2 pack)', 399),
#  (1273755, 'Duff', 'Batteries (AAA, 2 pack)', 379),
#  (1274523, 'Duff', 'Network Switch (Gigabit, 24-port)', 13159),
#  (1274520, 'Duff', 'Network Switch (Gigabit, 24-port)', 12789),
#  (1274519, 'Duff', 'Network Switch (Gigabit, 16-port)', 7989),
#  (1273956, 'Duff', 'BNC Plug to UHF Jack', 559),
#  (1274513, 'Duff', 'Network Switch (Gigabit, 8-port)', 6639),
#  (1273957, 'Duff', 'BNC Jack to UHF Plug', 579),
#  (1274499, 'Duff', 'VPN Appliance (50 Clienti license)', 50029),
#  (1273877, 'Duff', 'Laptop Cooling Pad', 4209),
#  (1273902, 'Duff', '3.5mm Mini Male to RCA Phono Female Adapter', 409),
#  (1274031, 'Duff', '1GB DDR2-667 (PC2-5300) Desktop Memory Kit (2x512MB)', 19),
#  (1273766, 'Duff', 'Rechargeable Batteries (AA, 4 pack)', 2759),
#  (1273923, 'Duff', 'RCA Phono Female to Female, Barrel Adapter', 499),
#  (1273661, 'Duff', 'Composite AV Cable (72 in.)', 2589),
#  (1274485, 'Duff', 'Wireless N USB Adapter', 6489),
#  (1273771, 'Duff', 'Rechargeable Batteries (C, 2 pack)', 1889),
#  (1273778, 'Duff', 'Keyboard (basic PC101)', 2799),
#  (1274006, 'Duff', 'S-Video Female-to-Female Cable (24 in.)', 1559),
#  (1273655, 'Duff', 'Composite AV Cable (36 in.)', 2539),
#  (1273995, 'Duff', 'Phono Jack to F Plug', 459),
#  (1273830, 'Duff', 'UPS 1200 Watt', 16249),
#  (1273982, 'Duff', 'F Jack Male-to-Male Cable (36 in.)', 1819),
#  (1273717, 'Duff', 'Screen Cleaning Cloth (white)', 1969),
#  (1273964, 'Duff', 'Phono Plug to UHF Jack', 649),
#  (1273848, 'Duff', 'Surge Protector (4-Outlet)', 1749),
#  (1274467, 'Duff', 'ADSL Modem + Wireless N Router', 8969),
#  (1273694, 'Ultramegaco', 'Case for Notebook Computer', 4499),
#  (1273719, 'Ultramegaco', 'Screen Cleaning Cloth (gray)', 1839),
#  (1274391, 'Ultramegaco', '21" LED Backlit Monitor', 24859),
#  (1274376, 'Ultramegaco', '24" Wide Screen LCD Monitor', 22909),
#  (1274366, 'Ultramegaco', '19" Wide Screen LCD Monitor', 13359),
#  (1273642, 'Ultramegaco', 'USB Card Reader', 1949),
#  (1273847, 'Ultramegaco', 'Surge Protector (6-Outlet, angled plug)', 2599),
#  (1273979, 'Ultramegaco', 'F Jack Male-to-Male Cable (36 in.)', 1949),
#  (1274240, 'Ultramegaco', 'Fireware 800 Card (PCI)', 7089),
#  (1273984, 'Ultramegaco', 'F Jack Male-to-Male Cable (36 in.)', 1909),
#  (1274282, 'Ultramegaco', '2x1GB Value DDR2 - 667 RAM', 13079),
#  (1274278, 'Ultramegaco', '2x2GB DDR3 1600MHz Desktop RAM', 21179),
#  (1274269, 'Ultramegaco', '1024MB PCI-X Graphics Card with HDMI output (OEM)', 9939),
#  (1274259, 'Ultramegaco', '512MB PCI-X Graphics Card (OEM)', 7959),
#  (1273987, 'Ultramegaco', 'F Jack Male-to-Male Cable (60 in.)', 2629),
#  (1273652, 'Ultramegaco', 'Composite AV Cable (24 in.)', 2329),
#  (1273693, 'Ultramegaco', 'Case for Notebook Computer', 4869),
#  (1273818, 'Ultramegaco', 'Battery Charger', 3249),
#  (1273678, 'Ultramegaco', 'High Speed HDMI Cable (60 in.)', 5049),
#  (1273960, 'Ultramegaco', 'Phono Plug to BNC Jack', 599),
#  (1273883, 'Ultramegaco', 'USB 2.0 4-Port Mini Hub', 2369),
#  (1273948, 'Ultramegaco', '1/4 in. Standard Phone Male to 3.5mm Mini Female Adapter', 309),
#  (1273803, 'Ultramegaco', 'Wireless laser mouse (three button, with wheel)', 4069),
#  (1273798, 'Ultramegaco', 'Wired mouse (three button, with wheel)', 4019),
#  (1274207, 'Ultramegaco', 'Full Tower Computer Case', 12879),
#  (1273791, 'Ultramegaco', 'Keyboard (wireless, with trackball)', 13689),
#  (1274018, 'Ultramegaco', '16GB DDR3-1600 (PC3-12800) Dual Channel Desktop Memory Kit (2x8GB)', 159),
#  (1274019, 'Ultramegaco', '8GB DDR3-1600 (PC3-12800) Dual Channel Desktop Memory Kit (2x4GB)', 119),
#  (1274028, 'Ultramegaco', '1GB DDR2-667 (PC2-5300) Desktop Memory Kit (2x512MB)', 29),
#  (1273924, 'Ultramegaco', 'RCA Phono Female to Female, Barrel Adapter', 519),
#  (1273765, 'Ultramegaco', 'Rechargeable Batteries (AA, 4 pack)', 2799),
#  (1273875, 'Ultramegaco', 'Extension cord (50 ft., outdoor)', 7329),
#  (1273763, 'Ultramegaco', 'Batteries (9V, 1 pack)', 629),
#  (1273756, 'Ultramegaco', 'Batteries (C, 2 pack)', 809),
#  (1274185, 'Ultramegaco', 'ATX Computer Case', 6039),
#  (1274125, 'Ultramegaco', '5.25" Drive Bay Adapter', 1299),
#  (1274173, 'Ultramegaco', 'Black 8X BD-ROM 16X DVD-ROM', 8059),
#  (1273856, 'Ultramegaco', 'Extension cord (36 in.)', 1759),
#  (1274126, 'Ultramegaco', '3.5" Drive Bay Adapter', 1529),
#  (1274146, 'United Digistuff', 'USB 3.0 Card Reader', 829),
#  (1274177, 'United Digistuff', 'Black 16X DVD-ROM', 2509),
#  (1274658, 'United Digistuff', '8 GB USB Flash Drive ', 2799),
#  (1274661, 'United Digistuff', '8 GB USB Flash Drive ', 2939),
#  (1274190, 'United Digistuff', 'ATX Computer Case', 6049),
#  (1274196, 'United Digistuff', 'ITX Computer Case', 3949),
#  (1274631, 'United Digistuff', '1.5 TB SATA3 Disk', 12369),
#  (1274630, 'United Digistuff', '1.5 TB SATA3 Disk', 12619),
#  (1274626, 'United Digistuff', '1.0 TB SATA3 Disk (10K RPM)', 15219),
#  (1274619, 'United Digistuff', '750 GB SATA3 Disk', 10469),
#  (1274614, 'United Digistuff', '500 GB SATA3 Disk', 8579),
#  (1274611, 'United Digistuff', '173 GB SAS Disk', 47419),
#  (1274610, 'United Digistuff', '173 GB SAS Disk', 49459),
#  (1274217, 'United Digistuff', '3.4GHz CPU', 17919),
#  (1274717, 'United Digistuff', '64 GB SSD Disk', 22129),
#  (1274605, 'United Digistuff', '60 GB PATA Disk', 8719),
#  (1274234, 'United Digistuff', 'Power Supply (700W)', 2969),
#  (1274242, 'United Digistuff', 'SCSI Expansion Card (PCI)', 7939),
#  (1274244, 'United Digistuff', 'SCSI Expansion Card (PCI)', 7889),
#  (1274250, 'United Digistuff', '16MB VESA Graphics Card', 1969),
#  (1274302, 'United Digistuff', 'Soundcard (Basic)', 1319),
#  (1274306, 'United Digistuff', 'Server (2U rackmount, eight-core, 64GB, 12TB)', 597049),
#  (1274744, 'United Digistuff', '16 GB Micro SD', 4479),
#  (1274349, 'United Digistuff', 'Tablet PC (10 in. display, 64 GB)', 49579),
#  (1274359, 'United Digistuff', 'Tablet PC (7 in. display, 16 GB, WiFi-only)', 32589),
#  (1274749, 'United Digistuff', '32 GB Micro SD', 5989),
#  (1274303, 'United Digistuff', 'Soundcard (Basic)', 1289)]

# %% [markdown]
# **Step 2: Filtering produts from these brands that fall withing our price range**
#
# Use the above query as a subquery to feed the filter for the price range, as given below:

# %%
# %%sql
#
# SELECT prod_id, brand, name, price
# FROM products
# WHERE brand IN (
#     SELECT brand
#     FROM products
#     WHERE brand LIKE 'C%' OR brand LIKE 'D%' OR brand LIKE 'U%'
# )
# AND price BETWEEN 4500 AND 7500
# ORDER BY brand, price;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 31 rows affected.
# [(1274045, 'Chatter Audio', 'Multimedia Headset', 5529),
#  (1274042, 'Chatter Audio', 'Multimedia Headset', 5739),
#  (1273889, 'Chestnut', 'USB 3.0 4-Port Ultra Mini Hub', 4679),
#  (1273691, 'Chestnut', 'Case for Notebook Computer', 4839),
#  (1273720, 'Chestnut', 'Executive Stylus and Pen', 4849),
#  (1273726, 'Chestnut', '8-cell Battery', 6549),
#  (1273722, 'DevNull', '6-cell Battery', 4599),
#  (1273805, 'DevNull', 'Trackball', 4949),
#  (1274746, 'DevNull', '16 GB Micro SD (High Performance)', 5619),
#  (1274747, 'DevNull', '32 GB Micro SD', 6059),
#  (1274603, 'Dorx', '6 GB IDE Disk', 5209),
#  (1274676, 'Dorx', '32 GB USB Flash Drive', 5639),
#  (1274246, 'Dualcore', 'TV Tuner Card (PCI)', 4999),
#  (1273873, 'Dualcore', 'Extension cord (20 ft., outdoor)', 5049),
#  (1274047, 'Dualcore', 'Multi-Performance PC Headset', 5129),
#  (1274044, 'Dualcore', 'Multimedia Headset', 5609),
#  (1273680, 'Dualcore', 'High Speed HDMI Cable (72 in.)', 5839),
#  (1274529, 'Dualcore', 'Ethernet NIC (Gigabit)', 6139),
#  (1274482, 'Dualcore', 'Wireless N USB Adapter', 6559),
#  (1274480, 'Dualcore', 'Wireless N Router', 6889),
#  (1274514, 'Dualcore', 'Network Switch (Gigabit, 8-port)', 6899),
#  (1274066, 'Dualcore', 'Stereo Component 8-Track Player', 6919),
#  (1274485, 'Duff', 'Wireless N USB Adapter', 6489),
#  (1274513, 'Duff', 'Network Switch (Gigabit, 8-port)', 6639),
#  (1273693, 'Ultramegaco', 'Case for Notebook Computer', 4869),
#  (1273678, 'Ultramegaco', 'High Speed HDMI Cable (60 in.)', 5049),
#  (1274185, 'Ultramegaco', 'ATX Computer Case', 6039),
#  (1274240, 'Ultramegaco', 'Fireware 800 Card (PCI)', 7089),
#  (1273875, 'Ultramegaco', 'Extension cord (50 ft., outdoor)', 7329),
#  (1274749, 'United Digistuff', '32 GB Micro SD', 5989),
#  (1274190, 'United Digistuff', 'ATX Computer Case', 6049)]

# %% [markdown]
# ## Example 8: A Real-world Scenario
#
# Our e-Commerce company, Dualcore, ran a video sharing contest where customers shared their videos using their tablets in creative ways. A reward of $5,000 would be awarded to the video having the highest rating.
# Unfortunately, due to a database crash, the registration data was lost. Now the only information they have are the videos and about the winner that she introduced herself as “Bridget from Kansas City” in the video.
# Run a query to find the winner’s record from company's customer database.

# %%
# %%sql
#
# SELECT *
# FROM customers
# WHERE fname LIKE 'Bridg%'
#     AND city = 'Kansas City';
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 1 rows affected.
# [(1139477, 'Bridget', 'Burch', '1644 East 7th Street', 'Kansas City', 'KS', '66119')]

# %% [markdown]
# ## Example 9: Busiest Time of the Day
#
# The `order_date` column in the `orders` table is a `timestamp` column that provides the time of the order, down to the second. Use this to determine which are the busy times of day.

# %%
# %%sql
#
# SELECT DATE_FORMAT(order_date, '%H:00 - %H:59') AS busy_time_of_day, COUNT(*) AS total_orders
# FROM orders
# GROUP BY DATE_FORMAT(order_date, '%H:00 - %H:59')
# ORDER BY total_orders DESC;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 1 rows affected.
# [('00:00 - 00:59', 1662951)]

# %% [markdown]
# In this query, we are using the `DATE_FORMAT` function to extract the hour from the `order_date` column in the `orders` table. The format `'%H'` represents the hour in 24-hour format. The result will be displayed as a range of hours from 'HH:00' to 'HH:59' (e.g., 01:00 - 01:59, 02:00 - 02:59, and so on).
#
# Next, we use the `GROUP BY` clause to group the orders based on the extracted hour. The `COUNT(*)` function counts the number of orders for each hour. The results will be ordered in descending order of total orders using the `ORDER BY` clause.

# %% [markdown]
# ### Example 9.1: Top-3 most active and Top-3 least busy times of the day
#
# Which are the three most active hours, and the three least active hours, for Dualcore orders?

# %%
# %%sql
#
# SELECT DATE_FORMAT(order_date, '%H') AS hour_range,
#        COUNT(*) AS total_orders
# FROM orders
# GROUP BY DATE_FORMAT(order_date, '%H')
# ORDER BY total_orders DESC
# LIMIT 3;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 3 rows affected.
# [('15', 86883), ('12', 86778), ('09', 86741)]

# %%
# %%sql
#
# -- For the three least active hours
# SELECT DATE_FORMAT(order_date, '%H') AS hour_range,
#        COUNT(*) AS total_orders
# FROM orders
# GROUP BY DATE_FORMAT(order_date, '%H')
# ORDER BY total_orders
# LIMIT 3;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 3 rows affected.
# [('02', 22745), ('03', 26483), ('04', 29606)]

# %% [markdown]
# ## Example 10: profit Margin
#
# In the products table, the price column is what the customer pays for an item. The cost column gives the wholesale cost that Dualcore pays for the item. The profit on an item is the difference between what the customer pays and what Dualcore pays.

# %% [markdown]
# ### Example 10.1. Find the five items that provide the largest profit. (They should all be servers.)

# %%
# %%sql
#
# SELECT prod_id, name, brand, (price - cost) AS profit
# FROM products
# WHERE name LIKE '%Server%'
# ORDER BY profit DESC
# LIMIT 5;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 5 rows affected.
# [(1274315, 'Server (1U rackmount, hex-core, 16GB, 8TB)', 'Sparky', 91177),
#  (1274319, 'Server (1U rackmount, hex-core, 32GB, 8TB)', 'BuckLogix', 88560),
#  (1274313, 'Server (1U rackmount, hex-core, 8GB, 4TB)', 'Olde-Gray', 71303),
#  (1274306, 'Server (2U rackmount, eight-core, 64GB, 12TB)', 'United Digistuff', 63786),
#  (1274320, 'Server (1U rackmount, hex-core, 32GB, 8TB)', 'Sparky', 61366)]

# %% [markdown]
# ### Example 10.2. What items are selling at no profit or at a loss? Find such top 5 items.

# %%
# %%sql
#
# SELECT prod_id, name, (price - cost) AS profit
# FROM products
# WHERE (price - cost) <= 0
# ORDER BY profit
# LIMIT 5;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 3 rows affected.
# [(1274348, 'Tablet PC (10 in. display, 64 GB)', -104),
#  (1274021, '8GB DDR3-1600 (PC3-12800) Dual Channel Desktop Memory Kit (2x4GB)', 0),
#  (1274136, 'Fan Adapter Cable - 16 inch', 0)]

# %% [markdown]
# ### Example 10.3. Handling NULL values.
#
# If either of columns - price or cost - have a `NULL` value for a product, then that row must not be considered in finding the profit/loss margin in the previous queries. To check how complete the `Products` dataset is, do the following.
# 1. First check either of the columns for NULL values.

# %%
# %%sql
#
# SELECT prod_id, name, price, cost
# FROM products
# WHERE price IS NULL OR cost IS NULL;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 0 rows affected.
# []

# %% [markdown]
# The 0 rows returned indicate that no record in our dataset has NULL (missing) value for either the price or the cost columns.

# %% [markdown]
# ## Example 11. Aggregating Values
#
# In SQL, aggregate values are the results of applying aggregate functions to a set of rows in a database table. These functions perform calculations on a group of rows and return a single value that represents a summary or an aggregate of the data within that group. Aggregate functions are commonly used to obtain useful insights and statistics from large datasets.
#
# Here are the aggregate functions in SQL:
#
# 1. **`COUNT()`**: Returns the number of rows in a specified column or the number of rows that match a specific condition.
# 2. **`SUM()`**: Calculates the sum of values in a numeric column.
# 3. **`AVG()`**: Calculates the average of values in a numeric column.
# 4. **`MIN()`**: Retrieves the minimum value from a column.
# 5. **`MAX()`**: Retrieves the maximum value from a column.
#
# These aggregate functions are particularly useful when you want to analyze data across multiple rows and obtain summarized information, such as the total count, the average value, or the highest and lowest values within a dataset. When using aggregate functions, it's essential to group the data appropriately using the GROUP BY clause to get meaningful results for subsets of data rather than the entire table.
#
# As aggreagate functions and grouping of data are very important aspects of data analytics, we will be covering them extensively in a future lab. This lab just introduces the `AVG()` function to give you a glimpse into their power.

# %% [markdown]
# ### Ex 11.1. Average Values
#
# Write a query to find the average cost, average price, and average profit of all the items the company  carries. Format the result to show the currency symbol and up to two decimal places only.

# %%
# %%sql
#
# SELECT
#   FORMAT(AVG(cost), 2) AS average_cost,
#   FORMAT(AVG(price), 2) AS average_price,
#   FORMAT(AVG(price - cost), 2) AS average_profit
# FROM products
# WHERE price IS NOT NULL AND cost IS NOT NULL;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 1 rows affected.
# [('18,116.96', '21,121.24', '3,004.28')]

# %% [markdown]
# ### Ex 11.2. Average by Groups
#
# Modify the previous query to find the same averages for each brand and round the averages to the nearest dollar (your result should have 47 rows).

# %% [markdown]
# %%sql
#
# SELECT
#   brand,
#   ROUND(AVG(cost)) AS average_cost,
#   ROUND(AVG(price)) AS average_price,
#   ROUND(AVG(price - cost)) AS average_profit
# FROM products
# WHERE price IS NOT NULL AND cost IS NOT NULL
# GROUP BY brand;

# %% [markdown]
# ### Ex 11.3 Averages of Groups with Filters
# Modify the query to filter the results, so you only get those brands with an average profit greater than $2000 (32 rows).

# %%
# %%sql
#
# SELECT
#   brand,
#   ROUND(AVG(cost)) AS average_cost,
#   ROUND(AVG(price)) AS average_price,
#   ROUND(AVG(price - cost)) AS average_profit
# FROM products
# WHERE price IS NOT NULL AND cost IS NOT NULL
# GROUP BY brand
# HAVING AVG(price - cost) > 2000;
# Out:
#  * mysql://root:***@localhost:3306/dualcore
# 32 rows affected.
# [('Chestnut', Decimal('6386'), Decimal('9077'), Decimal('2691')),
#  ('McDowell', Decimal('18667'), Decimal('22983'), Decimal('4316')),
#  ('Dualcore', Decimal('15452'), Decimal('17918'), Decimal('2466')),
#  ('Orion', Decimal('10800'), Decimal('12881'), Decimal('2081')),
#  ('Gigabux', Decimal('30980'), Decimal('35749'), Decimal('4769')),
#  ('Tyrell', Decimal('10813'), Decimal('13476'), Decimal('2663')),
#  ('Lemmon', Decimal('36079'), Decimal('40454'), Decimal('4375')),
#  ('Dorx', Decimal('10022'), Decimal('12373'), Decimal('2351')),
#  ('Wernham', Decimal('23776'), Decimal('29290'), Decimal('5514')),
#  ('Weisenheimer', Decimal('14258'), Decimal('17380'), Decimal('3122')),
#  ('Artie', Decimal('22017'), Decimal('28839'), Decimal('6822')),
#  ('ARCAM', Decimal('34904'), Decimal('41482'), Decimal('6577')),
#  ('Argo', Decimal('23416'), Decimal('27021'), Decimal('3605')),
#  ('Sparky', Decimal('56875'), Decimal('67018'), Decimal('10143')),
#  ('BuckLogix', Decimal('56998'), Decimal('66960'), Decimal('9962')),
#  ('Electrosaurus', Decimal('27452'), Decimal('31688'), Decimal('4236')),
#  ('United Digistuff', Decimal('30335'), Decimal('34705'), Decimal('4370')),
#  ('SuperGamer', Decimal('28738'), Decimal('31556'), Decimal('2818')),
#  ('Krustybitz', Decimal('90298'), Decimal('97908'), Decimal('7611')),
#  ('Yoyodyne', Decimal('174252'), Decimal('184237'), Decimal('9984')),
#  ('Olde-Gray', Decimal('53184'), Decimal('61723'), Decimal('8539')),
#  ('Byteweasel', Decimal('84389'), Decimal('87425'), Decimal('3036')),
#  ('Homertech', Decimal('14911'), Decimal('17302'), Decimal('2391')),
#  ('Bitmonkey', Decimal('129646'), Decimal('142142'), Decimal('12497')),
#  ('Sprite', Decimal('20863'), Decimal('27507'), Decimal('6644')),
#  ('Wolfpack', Decimal('16337'), Decimal('20923'), Decimal('4586')),
#  ('Whiteacre', Decimal('29858'), Decimal('35401'), Decimal('5543')),
#  ('Foocorp', Decimal('34978'), Decimal('42750'), Decimal('7773')),
#  ('Bytefortress', Decimal('14413'), Decimal('23259'), Decimal('8846')),
#  ('Bitbucket', Decimal('11092'), Decimal('13572'), Decimal('2480')),
#  ('Spindown', Decimal('12033'), Decimal('15660'), Decimal('3627')),
#  ('Tortoise', Decimal('10656'), Decimal('13099'), Decimal('2443'))]

# %% [markdown]
# # **End of the Exercise**
